# %%
import validation_library as veri   
import os  
import importlib

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

importlib.reload(veri)

counter_greater_than_200 = 0

contract_lines_4X = []
contract_lines_8X = []

contracts_4X = veri.get_files("/home/matteo/FLAMES/validation-results/sb-heists/smartbugs-curated/0.4.x/contracts/dataset")
contracts_8X = veri.get_files("/home/matteo/FLAMES/validation-results/sb-heists/smartbugs-curated/0.8.x/contracts/dataset/arithmetic") 

for contract_path, contract_name in contracts_4X:
    contract, line = veri.find_occurrences(contract_path, "// <yes> <report>")
    if contract.count('\n') > 200:
        counter_greater_than_200 += 1 
    else:
        clean_contract = veri.replace_lines_with_string(contract, line, '')
        contract_lines_4X.append((contract_name, clean_contract, line))

for contract_path, contract_name in contracts_8X:
    contract, line = veri.find_occurrences(contract_path, "// <yes> <report>")
    
    if contract.count('\n') > 200:
        counter_greater_than_200 += 1
    else:
        clean_contract = veri.replace_lines_with_string(contract, line, '')
        contract_lines_8X.append((contract_name, clean_contract,line))

print(counter_greater_than_200, len(contracts_4X), len(contracts_8X))
veri.print_json_report("reports/contract_no_comment8X_2.json", contract_lines_8X)
veri.print_txt_report("reports/contract_no_comment8x_2.txt", contract_lines_8X)

veri.print_json_report("reports/contract_no_comment4X_2.json", contract_lines_4X)
veri.print_txt_report("reports/contract_no_comment4x_2.txt", contract_lines_4X)
# Out:
# 12 142 15

# %%
importlib.reload(veri)
contracts_with_results = veri.read_json_report("reports/contract_with_results_100k.json") #list of (replaced_contract, line, require)
contract_lines = veri.read_json_report("reports/contract_no_comment4X.json")  ##list of (contract_name, contract, line)

# %%
importlib.reload(veri)

##VL

contract = contract_lines[1]

for contract_patch in contracts_with_results[contract[0]]:    
        no_test, result = veri.evaluate_contracts(contract, contract_patch)
        print(result)

# %%
importlib.reload(veri)

##Precondition
contract = contract_lines[1]
contract_code = contract[1]
lines = contract[2]
precondition = lines["pre"] +1 
require = contracts_with_results[contract[0]][0][2]

contract_patch = veri.insert_empty_line(contract_code, precondition)
contract_patch = veri.replace_lines_with_string(contract_patch, [precondition], require) 

patch = (contract_patch, precondition, require)
no_test, result = veri.evaluate_contracts(contract, patch)
print(result)

# %%
importlib.reload(veri)

##Postcondition
contract = contract_lines[1]
contract_code = contract[1]
contract_patch_VL = contracts_with_results[contract[0]][0][1]
lines = contract[2]
precondition, postcondition = veri.find_function_bounds(contract[1], contract_patch_VL)
precondition = precondition + 1

require = contracts_with_results[contract[0]][0][2]

contract_patch = veri.insert_empty_line(contract_code, postcondition)
contract_patch = veri.replace_lines_with_string(contract_patch, [postcondition], require)
print(contract_patch)
patch = (contract_patch, postcondition, require)
no_test, result = veri.evaluate_contracts(contract, patch)
print(result)

# %%
#Pre+Post
contract = contract_lines[1]
contract_code = contract[1]
lines = contract[2]
postcondition = lines["post"] 
precondition = lines["pre"] +1

require = contracts_with_results[contract[0]][0][2]

contract_patch = veri.insert_empty_line(contract_code, postcondition)

contract_patch = veri.replace_lines_with_string(contract_patch, [postcondition], require)

 
contract_patch = veri.insert_empty_line(contract_patch, precondition)

contract_patch = veri.replace_lines_with_string(contract_patch, [precondition], require)
print(contract_patch)

patch = (contract_patch, postcondition, require)
no_test, result = veri.evaluate_contracts(contract, patch)
print(result)

# %%
##Pre+Post+VL

contract = contract_lines[4]
contract_code = contract[1]
lines = contract[2]
postcondition = lines["post"] 
precondition = lines["pre"] +1

require = contracts_with_results[contract[0]][0][2]

for contract_patched_VL in contracts_with_results[contract[0]]:  
    contract_patch = contract_patched_VL[0]
    if postcondition != contract_patch[1]: 
        contract_patch = veri.insert_empty_line(contract_patch, postcondition)
        contract_patch = veri.replace_lines_with_string(contract_patch, [postcondition], require)
    if precondition != contract_patch[1]: 
        contract_patch = veri.insert_empty_line(contract_patch, precondition)
        contract_patch= veri.replace_lines_with_string(contract_patch, [precondition], require) 
   
    print(contract_patch)
    patch_lines = f"{precondition},{contract_patched_VL[1]},{postcondition}"
    patch = (contract_patch, patch_lines, require)
    no_test, result = veri.evaluate_contracts(contract, patch)
    print(result)

# %%
##Pre+VL
contract = contract_lines[4]
contract_code = contract[1]
lines = contract[2]
precondition = lines["pre"] +1

require = contracts_with_results[contract[0]][0][2]

for contract_patched_VL in contracts_with_results[contract[0]]:  
    contract_patch = contract_patched_VL[0]
    if precondition != contract_patch[1]: 
        contract_patch = veri.insert_empty_line(contract_patch, precondition)
        contract_patch= veri.replace_lines_with_string(contract_patch, [precondition], require) 

    patch_lines = f"{precondition},{contract_patched_VL[1]}"
    patch = (contract_patch, patch_lines, require)
    no_test, result = veri.evaluate_contracts(contract, patch)
    print(result)

# %%
#Post+VL
contract = contract_lines[4]
contract_code = contract[1]
lines = contract[2]
postcondition = lines["post"] 


require = contracts_with_results[contract[0]][0][2]

for contract_patched_VL in contracts_with_results[contract[0]]:  
    contract_patch = contract_patched_VL[0]
    if postcondition != contract_patch[1]: 
        contract_patch = veri.insert_empty_line(contract_patch, postcondition)
        contract_patch = veri.replace_lines_with_string(contract_patch, [postcondition], require)
    print(contract_patch)
    patch_lines = f"{contract_patched_VL[1]},{postcondition}"
    patch = (contract_patch, patch_lines, require)
    no_test, result = veri.evaluate_contracts(contract, patch)
    print(result)

# %%
contracts_with_results = veri.read_json_report("reports/contract_with_results_20_4X.json") #list of (replaced_contract, line, require)
contract_lines = veri.read_json_report("reports/contract_no_comment4X.json")  ##list of (contract_name, contract, line)

# %%
importlib.reload(veri)
headers = [
    'Solidity_file_name',
    'vulnerability_type',
    'vulnerable_line_number',
    'vulnerability_function_entry_line',
    'vulnerability_function_end_line',
    'VL',
    'pre_post_',
    'pre',
    'post',
    'pre_VL_post',
    'pre_VL',
    'VL_post'
]

veri.create_csv_if_not_exists('/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv', headers)

for contract in contract_lines: 
        contract_name = contract[0]
        contract_code = contract[1]
        lines = contract[2]
        require = contracts_with_results[contract[0]][0][2]
        
        for contract_patch_VL in contracts_with_results[contract[0]]:  
                contract_patch = contract_patch_VL[0]
                VL = contract_patch_VL[1]
                precondition, postcondition = veri.find_function_bounds(contract[1], contract_patch_VL[1])
                precondition = precondition + 1
                # VL  
                no_test, result_VL = veri.evaluate_contracts(contract, contract_patch_VL)
                if no_test:
                        break

                # Pre
                contract_patch_pre = veri.insert_empty_line(contract_code, precondition)
                contract_patch_pre = veri.replace_lines_with_string(contract_patch_pre, [precondition], require) 
                patch_pre = (contract_patch_pre, precondition, require)
                no_test, result_pre = veri.evaluate_contracts(contract, patch_pre)

                # Post
                contract_patch_post = veri.insert_empty_line(contract_code, postcondition)
                contract_patch_post = veri.replace_lines_with_string(contract_patch_post, [postcondition], require)
                patch_post = (contract_patch_post, postcondition, require)
                no_test, result_post = veri.evaluate_contracts(contract, patch_post)
                

                # Pre + Post
                contract_patch_pre_post = veri.insert_empty_line(contract_code, postcondition)
                contract_patch_pre_post = veri.replace_lines_with_string(contract_patch_pre_post, [postcondition], require)
                contract_patch_pre_post = veri.insert_empty_line(contract_patch_pre_post, precondition)
                
                contract_patch_pre_post = veri.replace_lines_with_string(contract_patch_pre_post, [precondition ], require) 
                
                patch_lines = f"{precondition},{postcondition}"
                patch_pre_post = (contract_patch_pre_post, patch_lines, require)
                no_test, result_pre_post = veri.evaluate_contracts(contract, patch_pre_post)
             
                # Pre + VL + Post (PVP)
                if postcondition != VL: 
                        contract_patch_PVP = veri.insert_empty_line(contract_patch, postcondition)
                        contract_patch_PVP = veri.replace_lines_with_string(contract_patch_PVP, [postcondition], require)
                if precondition != VL: 
                        contract_patch_PVP = veri.insert_empty_line(contract_patch_PVP, precondition)
                        contract_patch_PVP= veri.replace_lines_with_string(contract_patch_PVP, [precondition], require) 

                patch_lines = f"{precondition},{contract_patch_VL[1]},{postcondition}"
                patch_PVP = (contract_patch_PVP, patch_lines, require)
                no_test, result_PVP = veri.evaluate_contracts(contract, patch_PVP)

                # Pre + VL (PV)
                contract_patch_PV = contract_patch
                if precondition != VL: 
                        contract_patch_PV = veri.insert_empty_line(contract_patch, precondition)
                        contract_patch_PV= veri.replace_lines_with_string(contract_patch_PV, [precondition], require) 

                patch_lines = f"{precondition},{contract_patch_VL[1]}"
                patch_PV = (contract_patch_PV, patch_lines, require)
                no_test, result_PV = veri.evaluate_contracts(contract, patch_PV)

                # VL + Post (VP)
                if postcondition != VL: 
                        contract_patch_VP = veri.insert_empty_line(contract_patch, postcondition)
                        contract_patch_VP = veri.replace_lines_with_string(contract_patch_VP, [postcondition], require)

                patch_lines = f"{contract_patch_VL[1]},{postcondition}"
                patch_VP = (contract_patch_VP, patch_lines, require)
                no_test, result_VP = veri.evaluate_contracts(contract, patch_VP)

            
                type_V = veri.get_directory_name(contract_name,"/home/matteo/FLAMES/validation-results/sb-heists/smartbugs-curated")
              

                row = {
                        'Solidity_file_name': contract_name,
                        'vulnerability_type': type_V,
                        'vulnerable_line_number': contract_patch_VL[1],
                        'vulnerability_function_entry_line': precondition - 1,
                        'vulnerability_function_end_line': postcondition,
                        'VL': result_VL,
                        'pre_post_': result_pre_post,
                        'pre': result_pre,
                        'post': result_post,
                        'pre_VL_post': result_PVP,
                        'pre_VL': result_PV,
                        'VL_post': result_VP
                }

                veri.append_row('/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv', headers, row)
###plausible_patch

                strategy_patch_map = {
                        'VL': contract_patch,  # codice con solo VL
                        'pre': contract_patch_pre,
                        'post': contract_patch_post,
                        'pre_post': contract_patch_pre_post,
                        'pre_VL_post': contract_patch_PVP,
                        'pre_VL': contract_patch_PV,
                        'VL_post': contract_patch_VP
                }

                veri.save_patches_by_strategy(
                        output_dir='/home/matteo/FLAMES/validation-results/sb-heists/patches_20k/',
                        contract_name=contract_name,
                        strategy_patch_map=strategy_patch_map
                )
# Out:
# CSV file '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' created successfully in Excel-friendly format.
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,15,20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(numbers<=382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(numbers<=382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(numbers<=382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,24] Evaluation Results:
# Inserted Require: require(numbers<=382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,17,24] Evaluation Results:
# Inserted Require: require(numbers<=382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,17] Evaluation Results:
# Inserted Require: require(numbers<=382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 17,24] Evaluation Results:
# Inserted Require: require(numbers<=382);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender.balance>=350*10**18);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender.balance>=350*10**18);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 26] Evaluation Results:
# Inserted Require: require(msg.sender.balance>=350*10**18);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,26] Evaluation Results:
# Inserted Require: require(msg.sender.balance>=350*10**18);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,16,26] Evaluation Results:
# Inserted Require: require(msg.sender.balance>=350*10**18);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,16] Evaluation Results:
# Inserted Require: require(msg.sender.balance>=350*10**18);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 16,26] Evaluation Results:
# Inserted Require: require(msg.sender.balance>=350*10**18);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 22] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,22,28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,22] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 22,28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 22] Evaluation Results:
# Inserted Require: require(!resolve[_name].exists);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(!resolve[_name].exists);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 31] Evaluation Results:
# Inserted Require: require(!resolve[_name].exists);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,31] Evaluation Results:
# Inserted Require: require(!resolve[_name].exists);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,22,31] Evaluation Results:
# Inserted Require: require(!resolve[_name].exists);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,22] Evaluation Results:
# Inserted Require: require(!resolve[_name].exists);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 22,31] Evaluation Results:
# Inserted Require: require(!resolve[_name].exists);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 39] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 52] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,52] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,39,52] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,39] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 39,52] Evaluation Results:
# Inserted Require: require(number>=1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.value==0);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.value==0);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.value==0);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(msg.value==0);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,13,15] Evaluation Results:
# Inserted Require: require(msg.value==0);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,13] Evaluation Results:
# Inserted Require: require(msg.value==0);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(msg.value==0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 96] Evaluation Results:
# Inserted Require: require(_addr.call.value(_wei));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,96] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,16,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,16] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 16,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,13,15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,13] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 96] Evaluation Results:
# Inserted Require: require(_addr.call.value(_wei));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,96] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,13,17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,13] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 13,17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 93] Evaluation Results:
# Inserted Require: require(_wei<=Holders[_addr]);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92,99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92,93,99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92,93] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 93,99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,24,27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,24] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 96] Evaluation Results:
# Inserted Require: require(_addr.call.value(_wei));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 92,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 92,96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 92,96] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),to,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x52d2e0f9b01101a59b38a3d05c80b7618aeed984.sol ===
#
# [Patch on line 26] Evaluation Results:
# Inserted Require: require(Token(0xd2a4c91875a07c740680799768e67dfe7fd5d34e).transfer(addr,0wei));
#
# === Evaluating patches for contract: 0x52d2e0f9b01101a59b38a3d05c80b7618aeed984.sol ===
#
# [Patch on line 25] Evaluation Results:
# Inserted Require: require(Token(0xd2a4c91875a07c740680799768e67dfe7fd5d34e).transfer(addr,0wei));
#
# === Evaluating patches for contract: 0x52d2e0f9b01101a59b38a3d05c80b7618aeed984.sol ===
#
# [Patch on line 29] Evaluation Results:
# Inserted Require: require(Token(0xd2a4c91875a07c740680799768e67dfe7fd5d34e).transfer(addr,0wei));
#
# === Evaluating patches for contract: 0x52d2e0f9b01101a59b38a3d05c80b7618aeed984.sol ===
#
# [Patch on line 25,29] Evaluation Results:
# Inserted Require: require(Token(0xd2a4c91875a07c740680799768e67dfe7fd5d34e).transfer(addr,0wei));
#
# === Evaluating patches for contract: 0x52d2e0f9b01101a59b38a3d05c80b7618aeed984.sol ===
#
# [Patch on line 25,26,29] Evaluation Results:
# Inserted Require: require(Token(0xd2a4c91875a07c740680799768e67dfe7fd5d34e).transfer(addr,0wei));
#
# === Evaluating patches for contract: 0x52d2e0f9b01101a59b38a3d05c80b7618aeed984.sol ===
#
# [Patch on line 25,26] Evaluation Results:
# Inserted Require: require(Token(0xd2a4c91875a07c740680799768e67dfe7fd5d34e).transfer(addr,0wei));
#
# === Evaluating patches for contract: 0x52d2e0f9b01101a59b38a3d05c80b7618aeed984.sol ===
#
# [Patch on line 26,29] Evaluation Results:
# Inserted Require: require(Token(0xd2a4c91875a07c740680799768e67dfe7fd5d34e).transfer(addr,0wei));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xe894d54dca59cb53fe9cbc5155093605c7068220.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],_value));
#
# === Evaluating patches for contract: 0xe894d54dca59cb53fe9cbc5155093605c7068220.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],_value));
#
# === Evaluating patches for contract: 0xe894d54dca59cb53fe9cbc5155093605c7068220.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],_value));
#
# === Evaluating patches for contract: 0xe894d54dca59cb53fe9cbc5155093605c7068220.sol ===
#
# [Patch on line 12,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],_value));
#
# === Evaluating patches for contract: 0xe894d54dca59cb53fe9cbc5155093605c7068220.sol ===
#
# [Patch on line 12,16,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],_value));
#
# === Evaluating patches for contract: 0xe894d54dca59cb53fe9cbc5155093605c7068220.sol ===
#
# [Patch on line 12,16] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],_value));
#
# === Evaluating patches for contract: 0xe894d54dca59cb53fe9cbc5155093605c7068220.sol ===
#
# [Patch on line 16,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],_value));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x4051334adc52057aca763453820cb0e045076ef3.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4051334adc52057aca763453820cb0e045076ef3.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4051334adc52057aca763453820cb0e045076ef3.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4051334adc52057aca763453820cb0e045076ef3.sol ===
#
# [Patch on line 12,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4051334adc52057aca763453820cb0e045076ef3.sol ===
#
# [Patch on line 12,15,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4051334adc52057aca763453820cb0e045076ef3.sol ===
#
# [Patch on line 12,15] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4051334adc52057aca763453820cb0e045076ef3.sol ===
#
# [Patch on line 15,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xa1fceeff3acc57d257b917e30c4df661401d6431.sol ===
#
# [Patch on line 30] Evaluation Results:
# Inserted Require: require(vs[i]>0);
#
# === Evaluating patches for contract: 0xa1fceeff3acc57d257b917e30c4df661401d6431.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(vs[i]>0);
#
# === Evaluating patches for contract: 0xa1fceeff3acc57d257b917e30c4df661401d6431.sol ===
#
# [Patch on line 34] Evaluation Results:
# Inserted Require: require(vs[i]>0);
#
# === Evaluating patches for contract: 0xa1fceeff3acc57d257b917e30c4df661401d6431.sol ===
#
# [Patch on line 24,34] Evaluation Results:
# Inserted Require: require(vs[i]>0);
#
# === Evaluating patches for contract: 0xa1fceeff3acc57d257b917e30c4df661401d6431.sol ===
#
# [Patch on line 24,30,34] Evaluation Results:
# Inserted Require: require(vs[i]>0);
#
# === Evaluating patches for contract: 0xa1fceeff3acc57d257b917e30c4df661401d6431.sol ===
#
# [Patch on line 24,30] Evaluation Results:
# Inserted Require: require(vs[i]>0);
#
# === Evaluating patches for contract: 0xa1fceeff3acc57d257b917e30c4df661401d6431.sol ===
#
# [Patch on line 30,34] Evaluation Results:
# Inserted Require: require(vs[i]>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xbebbfe5b549f5db6e6c78ca97cac19d1fb03082c.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbebbfe5b549f5db6e6c78ca97cac19d1fb03082c.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbebbfe5b549f5db6e6c78ca97cac19d1fb03082c.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbebbfe5b549f5db6e6c78ca97cac19d1fb03082c.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbebbfe5b549f5db6e6c78ca97cac19d1fb03082c.sol ===
#
# [Patch on line 13,13,15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbebbfe5b549f5db6e6c78ca97cac19d1fb03082c.sol ===
#
# [Patch on line 13,13] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbebbfe5b549f5db6e6c78ca97cac19d1fb03082c.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xa46edd6a9a93feec36576ee5048146870ea2c3ae.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0xa46edd6a9a93feec36576ee5048146870ea2c3ae.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0xa46edd6a9a93feec36576ee5048146870ea2c3ae.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0xa46edd6a9a93feec36576ee5048146870ea2c3ae.sol ===
#
# [Patch on line 12,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0xa46edd6a9a93feec36576ee5048146870ea2c3ae.sol ===
#
# [Patch on line 12,15,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0xa46edd6a9a93feec36576ee5048146870ea2c3ae.sol ===
#
# [Patch on line 12,15] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0xa46edd6a9a93feec36576ee5048146870ea2c3ae.sol ===
#
# [Patch on line 15,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xd5967fed03e85d1cce44cab284695b41bc675b5c.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0xd5967fed03e85d1cce44cab284695b41bc675b5c.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0xd5967fed03e85d1cce44cab284695b41bc675b5c.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0xd5967fed03e85d1cce44cab284695b41bc675b5c.sol ===
#
# [Patch on line 12,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0xd5967fed03e85d1cce44cab284695b41bc675b5c.sol ===
#
# [Patch on line 12,15,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0xd5967fed03e85d1cce44cab284695b41bc675b5c.sol ===
#
# [Patch on line 12,15] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0xd5967fed03e85d1cce44cab284695b41bc675b5c.sol ===
#
# [Patch on line 15,19] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: proxy.sol ===
#
# [Patch on line 18] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: proxy.sol ===
#
# [Patch on line 18] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: proxy.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: proxy.sol ===
#
# [Patch on line 18,20] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: proxy.sol ===
#
# [Patch on line 18,18,20] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: proxy.sol ===
#
# [Patch on line 18,18] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: proxy.sol ===
#
# [Patch on line 18,20] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: mapping_write.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mapping_write.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mapping_write.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mapping_write.sol ===
#
# [Patch on line 16,21] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mapping_write.sol ===
#
# [Patch on line 16,19,21] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mapping_write.sol ===
#
# [Patch on line 16,19] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mapping_write.sol ===
#
# [Patch on line 19,21] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: incorrect_constructor_name3.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name3.sol ===
#
# [Patch on line 10] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name3.sol ===
#
# [Patch on line 32] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name3.sol ===
#
# [Patch on line 10,32] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name3.sol ===
#
# [Patch on line 10,16,32] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name3.sol ===
#
# [Patch on line 10,16] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name3.sol ===
#
# [Patch on line 16,32] Evaluation Results:
# Inserted Require: require(msg.value>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: unprotected0.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: unprotected0.sol ===
#
# [Patch on line 10] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: unprotected0.sol ===
#
# [Patch on line 39] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: unprotected0.sol ===
#
# [Patch on line 10,39] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: unprotected0.sol ===
#
# [Patch on line 10,24,39] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: unprotected0.sol ===
#
# [Patch on line 10,24] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: unprotected0.sol ===
#
# [Patch on line 24,39] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 30] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 27] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 33] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 27,33] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 27,30,33] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 27,30] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 30,33] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 37] Evaluation Results:
# Inserted Require: require(msg.sender==fibonacciLibrary);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 37] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 39] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 37,39] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 37,37,39] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 37,37] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
#
# === Evaluating patches for contract: FibonacciBalance.sol ===
#
# [Patch on line 37,39] Evaluation Results:
# Inserted Require: require(calculatedFibNumber>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: mycontract.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mycontract.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mycontract.sol ===
#
# [Patch on line 22] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mycontract.sol ===
#
# [Patch on line 19,22] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mycontract.sol ===
#
# [Patch on line 19,19,22] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mycontract.sol ===
#
# [Patch on line 19,19] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
#
# === Evaluating patches for contract: mycontract.sol ===
#
# [Patch on line 19,22] Evaluation Results:
# Inserted Require: require(msg.sender==owner);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: simple_suicide.sol ===
#
# [Patch on line 11] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: simple_suicide.sol ===
#
# [Patch on line 11] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: simple_suicide.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: simple_suicide.sol ===
#
# [Patch on line 11,16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: simple_suicide.sol ===
#
# [Patch on line 11,11,16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: simple_suicide.sol ===
#
# [Patch on line 11,11] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: simple_suicide.sol ===
#
# [Patch on line 11,16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: incorrect_constructor_name2.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name2.sol ===
#
# [Patch on line 11] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: incorrect_constructor_name2.sol ===
#
# [Patch on line 32] Evaluation Results:
# ...
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 17,19] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 17,17,19] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 17,17] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 17,19] Evaluation Results:
# Inserted Require: require(input<2**256-1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 23] Evaluation Results:
# Inserted Require: require(input<2**256);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 23] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 25] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 23,25] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 23,23,25] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 23,23] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 23,25] Evaluation Results:
# Inserted Require: require(input<2**256-1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 29] Evaluation Results:
# Inserted Require: require(input<count);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 29] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 31] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 29,31] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 29,29,31] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 29,29] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 29,31] Evaluation Results:
# Inserted Require: require(input<2**256-1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 35] Evaluation Results:
# Inserted Require: require(input<count);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 35] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 37] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 35,37] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 35,35,37] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 35,35] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 35,37] Evaluation Results:
# Inserted Require: require(input<2**256-1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 41] Evaluation Results:
# Inserted Require: require(input!=0);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 41] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 41,43] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 41,41,43] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 41,41] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 41,43] Evaluation Results:
# Inserted Require: require(input<2**256-1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47] Evaluation Results:
# Inserted Require: require(input<count);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 49] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47,49] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47,47,49] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47,47] Evaluation Results:
# Inserted Require: require(input<2**256-1);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47,49] Evaluation Results:
# Inserted Require: require(input<2**256-1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(count<2);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(count<2);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 18] Evaluation Results:
# Inserted Require: require(count<2);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,18] Evaluation Results:
# Inserted Require: require(count<2);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,16,18] Evaluation Results:
# Inserted Require: require(count<2);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,16] Evaluation Results:
# Inserted Require: require(count<2);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,18] Evaluation Results:
# Inserted Require: require(count<2);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 23] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17,23] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17,21,23] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17,21] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 21,23] Evaluation Results:
# Inserted Require: require(input>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,21,23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,21] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 26] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21,26] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21,24,26] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21,24] Evaluation Results:
# Inserted Require: require(input>0);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 24,26] Evaluation Results:
# Inserted Require: require(input>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 42] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 57] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,57] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,42,57] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,42] Evaluation Results:
# Inserted Require: require(msg.value>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 42,57] Evaluation Results:
# Inserted Require: require(msg.value>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(now>=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(now>=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 14] Evaluation Results:
# Inserted Require: require(now>=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,14] Evaluation Results:
# Inserted Require: require(now>=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,12,14] Evaluation Results:
# Inserted Require: require(now>=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,12] Evaluation Results:
# Inserted Require: require(now>=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,14] Evaluation Results:
# Inserted Require: require(now>=1546300800);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,24] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,17,24] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,17] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 17,24] Evaluation Results:
# Inserted Require: require(now%15==0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(now%15==14);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,24] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,19,24] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,19] Evaluation Results:
# Inserted Require: require(now%15==0);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 19,24] Evaluation Results:
# Inserted Require: require(now%15==0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_20K.csv' (Excel-friendly format).

# %%
contracts_with_results = veri.read_json_report("reports/contract_with_results_100k.json") #list of (replaced_contract, line, require)
contract_lines = veri.read_json_report("reports/contract_no_comment4X_2.json")  ##list of (contract_name, contract, line)

# %%
importlib.reload(veri)
headers = [
    'Solidity_file_name',
    'vulnerability_type',
    'vulnerable_line_number',
    'vulnerability_function_entry_line',
    'vulnerability_function_end_line',
    'VL',
    'pre_post_',
    'pre',
    'post',
    'pre_VL_post',
    'pre_VL',
    'VL_post'
]

veri.create_csv_if_not_exists('/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100k.csv', headers)

for contract in contract_lines: 
        contract_name = contract[0]
        contract_code = contract[1]
        lines = contract[2]
        require = contracts_with_results[contract[0]][0][2]
        
        for contract_patch_VL in contracts_with_results[contract[0]]:  
                contract_patch = contract_patch_VL[0]
                precondition, postcondition = veri.find_function_bounds(contract[1], contract_patch_VL[1])
                precondition = precondition + 1
                # VL  
                no_test, result_VL = veri.evaluate_contracts(contract, contract_patch_VL)
                if no_test:
                        break

                # Pre
                
                contract_patch_pre = veri.insert_empty_line(contract_code, precondition)
                contract_patch_pre = veri.replace_lines_with_string(contract_patch_pre, [precondition], require) 
                patch_pre = (contract_patch_pre, precondition, require)
                no_test, result_pre = veri.evaluate_contracts(contract, patch_pre)
                print(contract_patch_pre)

                # Post
                contract_patch_post = veri.insert_empty_line(contract_code, postcondition)
                contract_patch_post = veri.replace_lines_with_string(contract_patch_post, [postcondition], require)
                patch_post = (contract_patch_post, postcondition, require)
                no_test, result_post = veri.evaluate_contracts(contract, patch_post)

                # Pre + Post
                contract_patch_pre_post = veri.insert_empty_line(contract_code, postcondition)
                contract_patch_pre_post = veri.replace_lines_with_string(contract_patch_pre_post, [postcondition], require)
                contract_patch_pre_post = veri.insert_empty_line(contract_patch_pre_post, precondition)
                contract_patch_pre_post = veri.replace_lines_with_string(contract_patch_pre_post, [precondition], require) 
                
                patch_lines = f"{precondition},{postcondition}"
                patch_pre_post = (contract_patch_pre_post, patch_lines, require)
                no_test, result_pre_post = veri.evaluate_contracts(contract, patch_pre_post)

                # Pre + VL + Post (PVP)
                if postcondition != contract_patch[1]: 
                        contract_patch_PVP = veri.insert_empty_line(contract_patch, postcondition)
                        contract_patch_PVP = veri.replace_lines_with_string(contract_patch_PVP, [postcondition], require)
                if precondition != contract_patch[1]: 
                        contract_patch_PVP = veri.insert_empty_line(contract_patch_PVP, precondition)
                        contract_patch_PVP= veri.replace_lines_with_string(contract_patch_PVP, [precondition], require) 

                patch_lines = f"{precondition},{contract_patch_VL[1]},{postcondition}"
                patch_PVP = (contract_patch_PVP, patch_lines, require)
                no_test, result_PVP = veri.evaluate_contracts(contract, patch_PVP)

                # Pre + VL (PV)
                if precondition != contract_patch[1]: 
                        contract_patch_PV = veri.insert_empty_line(contract_patch, precondition)
                        contract_patch_PV= veri.replace_lines_with_string(contract_patch_PV, [precondition], require) 

                patch_lines = f"{precondition},{contract_patch_VL[1]}"
                patch_PV = (contract_patch_PV, patch_lines, require)
                no_test, result_PV = veri.evaluate_contracts(contract, patch_PV)

                # VL + Post (VP)
                if postcondition != contract_patch[1]: 
                        contract_patch_VP = veri.insert_empty_line(contract_patch, postcondition)
                        contract_patch_VP = veri.replace_lines_with_string(contract_patch_VP, [postcondition], require)

                patch_lines = f"{contract_patch_VL[1]},{postcondition}"
                patch_VP = (contract_patch_VP, patch_lines, require)
                no_test, result_VP = veri.evaluate_contracts(contract, patch_VP)

            
                type_V = veri.get_directory_name(contract_name,"/home/matteo/FLAMES/validation-results/sb-heists/smartbugs-curated")
              

                row = {
                'Solidity_file_name': contract_name,
                'vulnerability_type': type_V,
                'vulnerable_line_number': contract_patch_VL[1],
                'vulnerability_function_entry_line': precondition - 1,
                'vulnerability_function_end_line': postcondition,
                'VL': result_VL,
                'pre_post_': result_pre_post,
                'pre': result_pre,
                'post': result_post,
                'pre_VL_post': result_PVP,
                'pre_VL': result_PV,
                'VL_post': result_VP
                }

                veri.append_row('/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv', headers, row)

                strategy_patch_map = {
                        'VL': contract_patch,  # codice con solo VL
                        'pre': contract_patch_pre,
                        'post': contract_patch_post,
                        'pre_post': contract_patch_pre_post,
                        'pre_VL_post': contract_patch_PVP,
                        'pre_VL': contract_patch_PV,
                        'VL_post': contract_patch_VP
                }

                veri.save_patches_by_strategy(
                        output_dir='/home/matteo/FLAMES/validation-results/sb-heists/patches_100k/',
                        contract_name=contract_name,
                        strategy_patch_map=strategy_patch_map
                )
# Out:
# CSV file '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100k.csv' created successfully in Excel-friendly format.
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# /*
#  * @source: https://github.com/SmartContractSecurity/SWC-registry/blob/master/test_cases/dos_gas_limit/dos_address.sol
#  * @author: -
#  * @vulnerable_at_lines: 16,17,18
#  */
#
# pragma solidity ^0.4.25;
#
# contract DosGas {
#
#     address[] creditorAddresses;
#     bool win = false;
#
#     function emptyCreditors() public {
# require(msg.sender==tx.origin);
#
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function addCreditors() public returns (bool) {
#         for(uint i=0;i<350;i++) {
#           creditorAddresses.push(msg.sender);
#         }
#         return true;
#     }
#
#     function iWin() public view returns (bool) {
#         return win;
#     }
#
#     function numberCreditors() public view returns (uint) {
#         return creditorAddresses.length;
#     }
# }
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,15,20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,20] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(numbers<382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(numbers<382);
# /*
#  * @source: https://github.com/SmartContractSecurity/SWC-registry/blob/master/test_cases/dos_gas_limit/dos_number.sol
#  * @author: -
#  * @vulnerable_at_lines: 18,19,20,21,22
#  */
#
# pragma solidity ^0.4.25;
#
# contract DosNumber {
#
#     uint numElements = 0;
#     uint[] array;
#
#     function insertNnumbers(uint value,uint numbers) public {
# require(numbers<382);
# require(numbers<382);
#
#         // Gas DOS if number > 382 more or less, it depends on actual gas limit
# require(numbers<=382);
#         for(uint i=0;i<numbers;i++) {
#             if(numElements == array.length) {
#                 array.length += 1;
#             }
#             array[numElements++] = value;
#         }
#     }
#
#     function clear() public {
#         require(numElements>1500);
#         numElements = 0;
#     }
#
#     // Gas DOS clear
#     function clearDOS() public {
#
#         // number depends on actual gas limit
#         require(numElements>1500);
#         array = new uint[](0);
#         numElements = 0;
#     }
#
#     function getLengthArray() public view returns(uint) {
#         return numElements;
#     }
#
#     function getRealLengthArray() public view returns(uint) {
#         return array.length;
#     }
# }
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 25] Evaluation Results:
# Inserted Require: require(numbers<382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,25] Evaluation Results:
# Inserted Require: require(numbers<382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,17,25] Evaluation Results:
# Inserted Require: require(numbers<382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,17] Evaluation Results:
# Inserted Require: require(numbers<382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 17,25] Evaluation Results:
# Inserted Require: require(numbers<382);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# /*
#  * @source: https://github.com/SmartContractSecurity/SWC-registry/blob/master/test_cases/dos_gas_limit/dos_simple.sol
#  * @author: -
#  * @vulnerable_at_lines: 17,18
#  */
#
#
# pragma solidity ^0.4.25;
#
# contract DosOneFunc {
#
#     address[] listAddresses;
#
#     function ifillArray() public returns (bool){
# require(msg.sender==tx.origin);
#         if(listAddresses.length<1500) {
#
#             for(uint i=0;i<350;i++) {
#                 listAddresses.push(msg.sender);
#             }
#             return true;
#
#         } else {
#             listAddresses = new address[](0);
#             return false;
#         }
#     }
# }
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 26] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,26] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,16,26] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 16,26] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 22] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
# /*
#  * @source: https://github.com/trailofbits/not-so-smart-contracts/blob/master/denial_of_service/auction.sol
#  * @author: -
#  * @vulnerable_at_lines: 23
#  */
#
# pragma solidity ^0.4.15;
#
# //Auction susceptible to DoS attack
# contract DosAuction {
#   address currentFrontrunner;
#   uint currentBid;
#
#   //Takes in bid, refunding the frontrunner if they are outbid
#   function bid() payable {
# require(msg.sender.send(msg.value));
#     require(msg.value > currentBid);
#
#     //If the refund fails, the entire transaction reverts.
#     //Therefore a frontrunner who always fails will win
#     if (currentFrontrunner != 0) {
#       //E.g. if recipients fallback function is just revert()
#
#       require(currentFrontrunner.send(currentBid));
#     }
#
#     currentFrontrunner = msg.sender;
#     currentBid         = msg.value;
#   }
# }
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,22,28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,22] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 22,28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 22] Evaluation Results:
# Inserted Require: require(registeredNameRecord[msg.sender].name==0x0);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(registeredNameRecord[msg.sender].name==0x0);
# /*
#  * @source: https://github.com/sigp/solidity-security-blog#storage-example
#  * @vulnerable_at_lines: 21
#  */
# // A Locked Name Registrar
#
# pragma solidity ^0.4.15;
# contract NameRegistrar {
#
#     bool public unlocked = false;  // registrar locked, no name updates
#
#     struct NameRecord { // map hashes to addresses
#         bytes32 name;
#         address mappedAddress;
#     }
#
#     mapping(address => NameRecord) public registeredNameRecord; // records who registered names
#     mapping(bytes32 => address) public resolve; // resolves hashes to addresses
#
#     function register(bytes32 _name, address _mappedAddress) public {
# require(registeredNameRecord[msg.sender].name==0x0);
#         // set up the new NameRecord
#
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
# }
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 31] Evaluation Results:
# Inserted Require: require(registeredNameRecord[msg.sender].name==0x0);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,31] Evaluation Results:
# Inserted Require: require(registeredNameRecord[msg.sender].name==0x0);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,22,31] Evaluation Results:
# Inserted Require: require(registeredNameRecord[msg.sender].name==0x0);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,22] Evaluation Results:
# Inserted Require: require(registeredNameRecord[msg.sender].name==0x0);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 22,31] Evaluation Results:
# Inserted Require: require(registeredNameRecord[msg.sender].name==0x0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 39] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38] Evaluation Results:
# Inserted Require: require(number>=1);
# /*
#  * @source: https://github.com/thec00n/smart-contract-honeypots/blob/master/CryptoRoulette.sol
#  * @vulnerable_at_lines: 40,41,42
#  */
# pragma solidity ^0.4.19;
#
# // CryptoRoulette
# //
# // Guess the number secretly stored in the blockchain and win the whole contract balance!
# // A new number is randomly chosen after each try.
# // https://www.reddit.com/r/ethdev/comments/7wp363/how_does_this_honeypot_work_it_seems_like_a/
# // To play, call the play() method with the guessed number (1-20).  Bet price: 0.1 ether
#
# contract CryptoRoulette {
#
#     uint256 private secretNumber;
#     uint256 public lastPlayed;
#     uint256 public betPrice = 0.1 ether;
#     address public ownerAddr;
#
#     struct Game {
#         address player;
#         uint256 number;
#     }
#     Game[] public gamesPlayed;
#
#     function CryptoRoulette() public {
#         ownerAddr = msg.sender;
#         shuffle();
#     }
#
#     function shuffle() internal {
#         // randomly set secretNumber with a value between 1 and 20
#         secretNumber = uint8(sha3(now, block.blockhash(block.number-1))) % 20 + 1;
#     }
#
#     function play(uint256 number) payable public {
# require(number>=1);
#         require(msg.value >= betPrice && number <= 10);
#
#         Game game; //Uninitialized storage pointer
#         game.player = msg.sender;
#         game.number = number;
#         gamesPlayed.push(game);
#
#         if (number == secretNumber) {
#             // win!
#             msg.sender.transfer(this.balance);
#         }
#
#         shuffle();
#         lastPlayed = now;
#     }
#
#     function kill() public {
#         if (msg.sender == ownerAddr && now > lastPlayed + 1 days) {
#             suicide(msg.sender);
#         }
#     }
#
#     function() public payable { }
# }
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 52] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,52] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,39,52] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,39] Evaluation Results:
# Inserted Require: require(number>=1);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 39,52] Evaluation Results:
# Inserted Require: require(number>=1);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 14
#  */
#
# pragma solidity ^0.4.24;
#
# contract Proxy  {
#     modifier onlyOwner { if (msg.sender == Owner) _; } address Owner = msg.sender;
#     function transferOwner(address _owner) public onlyOwner { Owner = _owner; }
#     function proxy(address target, bytes data) public payable {
# require(msg.sender==tx.origin);
# require(msg.sender==tx.origin);
# require(msg.sender==tx.origin);
#         target.call.value(msg.value)(data);
# require(msg.sender==tx.origin);
#     }
# }
#
# contract DepositProxy is Proxy {
#     address public Owner;
#     mapping (address => uint256) public Deposits;
#
#     function () public payable { }
#
#     function Vault() public payable {
#         if (msg.sender == tx.origin) {
#             Owner = msg.sender;
#             deposit();
#         }
#     }
#
#     function deposit() public payable {
#         if (msg.value > 0.5 ether) {
#             Deposits[msg.sender] += msg.value;
#         }
#     }
#
#     function withdraw(uint256 amount) public onlyOwner {
#         if (amount>0 && Deposits[msg.sender]>=amount) {
#             msg.sender.transfer(amount);
#         }
#     }
# }
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,17] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,13,17] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,13] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,17] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 44,97
#  */
#
# pragma solidity ^0.4.18;
#
# contract Ownable
# {
#     address newOwner;
#     address owner = msg.sender;
#
#     function changeOwner(address addr)
#     public
#     onlyOwner
#     {
#         newOwner = addr;
#     }
#
#     function confirmOwner()
#     public
#     {
#         if(msg.sender==newOwner)
#         {
#             owner=newOwner;
#         }
#     }
#
#     modifier onlyOwner
#     {
#         if(owner == msg.sender)_;
#     }
# }
#
# contract Token is Ownable
# {
#     address owner = msg.sender;
#     function WithdrawToken(address token, uint256 amount,address to)
#     public
#     onlyOwner
#     {
# require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
#         token.call(bytes4(sha3("transfer(address,uint256)")),to,amount);
#     }
# }
#
# contract TokenBank is Token
# {
#     uint public MinDeposit;
#     mapping (address => uint) public Holders;
#
#      ///Constructor
#     function initTokenBank()
#     public
#     {
#         owner = msg.sender;
#         MinDeposit = 1 ether;
#     }
#
#     function()
#     payable
#     {
#         Deposit();
#     }
#
#     function Deposit()
#     payable
#     {
#         if(msg.value>MinDeposit)
#         {
#             Holders[msg.sender]+=msg.value;
#         }
#     }
#
#     function WitdrawTokenToHolder(address _to,address _token,uint _amount)
#     public
#     onlyOwner
#     {
#         if(Holders[_to]>0)
#         {
#             Holders[_to]=0;
#             WithdrawToken(_token,_amount,_to);
#         }
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
#
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#
# }
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 96] Evaluation Results:
# Inserted Require: require(_addr.send(_wei));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 44,97
#  */
#
# pragma solidity ^0.4.18;
#
# contract Ownable
# {
#     address newOwner;
#     address owner = msg.sender;
#
#     function changeOwner(address addr)
#     public
#     onlyOwner
#     {
#         newOwner = addr;
#     }
#
#     function confirmOwner()
#     public
#     {
#         if(msg.sender==newOwner)
#         {
#             owner=newOwner;
#         }
#     }
#
#     modifier onlyOwner
#     {
#         if(owner == msg.sender)_;
#     }
# }
#
# contract Token is Ownable
# {
#     address owner = msg.sender;
#     function WithdrawToken(address token, uint256 amount,address to)
#     public
#     onlyOwner
#     {
#
#         token.call(bytes4(sha3("transfer(address,uint256)")),to,amount);
#     }
# }
#
# contract TokenBank is Token
# {
#     uint public MinDeposit;
#     mapping (address => uint) public Holders;
#
#      ///Constructor
#     function initTokenBank()
#     public
#     {
#         owner = msg.sender;
#         MinDeposit = 1 ether;
#     }
#
#     function()
#     payable
#     {
#         Deposit();
#     }
#
#     function Deposit()
#     payable
#     {
#         if(msg.value>MinDeposit)
#         {
#             Holders[msg.sender]+=msg.value;
#         }
#     }
#
#     function WitdrawTokenToHolder(address _to,address _token,uint _amount)
#     public
#     onlyOwner
#     {
#         if(Holders[_to]>0)
#         {
#             Holders[_to]=0;
#             WithdrawToken(_token,_amount,_to);
#         }
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
#
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#
# }
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,96] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 17
#  */
#
# pragma solidity ^0.4.24;
#
#
# contract airPort{
#
#     function transfer(address from,address caddress,address[] _tos,uint v)public returns (bool){
# require(caddress.call(id,from,_tos[i],v));
#         require(_tos.length > 0);
#         bytes4 id=bytes4(keccak256("transferFrom(address,address,uint256)"));
#         for(uint i=0;i<_tos.length;i++){
#
#             caddress.call(id,from,_tos[i],v);
#         }
#         return true;
#     }
# }
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,16,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,16] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 16,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 14
#  */
#
# pragma solidity ^0.4.23;
#
# contract Proxy  {
#     modifier onlyOwner { if (msg.sender == Owner) _; } address Owner = msg.sender;
#     function transferOwner(address _owner) public onlyOwner { Owner = _owner; }
#     function proxy(address target, bytes data) public payable {
# require(msg.sender==tx.origin);
#
#         target.call.value(msg.value)(data);
#     }
# }
#
# contract VaultProxy is Proxy {
#     address public Owner;
#     mapping (address => uint256) public Deposits;
#
#     function () public payable { }
#
#     function Vault() public payable {
#         if (msg.sender == tx.origin) {
#             Owner = msg.sender;
#             deposit();
#         }
#     }
#
#     function deposit() public payable {
#         if (msg.value > 0.25 ether) {
#             Deposits[msg.sender] += msg.value;
#         }
#     }
#
#     function withdraw(uint256 amount) public onlyOwner {
#         if (amount>0 && Deposits[msg.sender]>=amount) {
#             msg.sender.transfer(amount);
#         }
#     }
# }
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,13,15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,13] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 44,97
#  */
#
# pragma solidity ^0.4.18;
#
# contract Ownable
# {
#     address newOwner;
#     address owner = msg.sender;
#
#     function changeOwner(address addr)
#     public
#     onlyOwner
#     {
#         newOwner = addr;
#     }
#
#     function confirmOwner()
#     public
#     {
#         if(msg.sender==newOwner)
#         {
#             owner=newOwner;
#         }
#     }
#
#     modifier onlyOwner
#     {
#         if(owner == msg.sender)_;
#     }
# }
#
# contract Token is Ownable
# {
#     address owner = msg.sender;
#     function WithdrawToken(address token, uint256 amount,address to)
#     public
#     onlyOwner
#     {
# require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
#         token.call(bytes4(sha3("transfer(address,uint256)")),to,amount);
#     }
# }
#
# contract TokenBank is Token
# {
#     uint public MinDeposit;
#     mapping (address => uint) public Holders;
#
#      ///Constructor
#     function initTokenBank()
#     public
#     {
#         owner = msg.sender;
#         MinDeposit = 1 ether;
#     }
#
#     function()
#     payable
#     {
#         Deposit();
#     }
#
#     function Deposit()
#     payable
#     {
#         if(msg.value>MinDeposit)
#         {
#             Holders[msg.sender]+=msg.value;
#         }
#     }
#
#     function WitdrawTokenToHolder(address _to,address _token,uint _amount)
#     public
#     onlyOwner
#     {
#         if(Holders[_to]>0)
#         {
#             Holders[_to]=0;
#             WithdrawToken(_token,_amount,_to);
#         }
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
#
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#     function Bal() public constant returns(uint){return this.balance;}
# }
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 96] Evaluation Results:
# Inserted Require: require(_addr.send(_wei));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 44,97
#  */
#
# pragma solidity ^0.4.18;
#
# contract Ownable
# {
#     address newOwner;
#     address owner = msg.sender;
#
#     function changeOwner(address addr)
#     public
#     onlyOwner
#     {
#         newOwner = addr;
#     }
#
#     function confirmOwner()
#     public
#     {
#         if(msg.sender==newOwner)
#         {
#             owner=newOwner;
#         }
#     }
#
#     modifier onlyOwner
#     {
#         if(owner == msg.sender)_;
#     }
# }
#
# contract Token is Ownable
# {
#     address owner = msg.sender;
#     function WithdrawToken(address token, uint256 amount,address to)
#     public
#     onlyOwner
#     {
#
#         token.call(bytes4(sha3("transfer(address,uint256)")),to,amount);
#     }
# }
#
# contract TokenBank is Token
# {
#     uint public MinDeposit;
#     mapping (address => uint) public Holders;
#
#      ///Constructor
#     function initTokenBank()
#     public
#     {
#         owner = msg.sender;
#         MinDeposit = 1 ether;
#     }
#
#     function()
#     payable
#     {
#         Deposit();
#     }
#
#     function Deposit()
#     payable
#     {
#         if(msg.value>MinDeposit)
#         {
#             Holders[msg.sender]+=msg.value;
#         }
#     }
#
#     function WitdrawTokenToHolder(address _to,address _token,uint _amount)
#     public
#     onlyOwner
#     {
#         if(Holders[_to]>0)
#         {
#             Holders[_to]=0;
#             WithdrawToken(_token,_amount,_to);
#         }
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
#
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#     function Bal() public constant returns(uint){return this.balance;}
# }
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,96] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 96,101] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 14
#  */
#
# pragma solidity ^0.4.25;
# contract demo{
#     function transfer(address from,address caddress,address[] _tos,uint[] v)public returns (bool){
# require(caddress.call(id,from,_tos[i],v[i]));
#         require(_tos.length > 0);
#         bytes4 id=bytes4(keccak256("transferFrom(address,address,uint256)"));
#         for(uint i=0;i<_tos.length;i++){
#
#             caddress.call(id,from,_tos[i],v[i]);
#         }
#         return true;
#     }
# }
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,13,17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,13] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 13,17] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v[i]));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 44
#  */
#
# pragma solidity ^0.4.19;
#
# contract Ownable
# {
#     address newOwner;
#     address owner = msg.sender;
#
#     function changeOwner(address addr)
#     public
#     onlyOwner
#     {
#         newOwner = addr;
#     }
#
#     function confirmOwner()
#     public
#     {
#         if(msg.sender==newOwner)
#         {
#             owner=newOwner;
#         }
#     }
#
#     modifier onlyOwner
#     {
#         if(owner == msg.sender)_;
#     }
# }
#
# contract Token is Ownable
# {
#     address owner = msg.sender;
#     function WithdrawToken(address token, uint256 amount,address to)
#     public
#     onlyOwner
#     {
# require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
#         token.call(bytes4(sha3("transfer(address,uint256)")),to,amount);
#     }
# }
#
# contract TokenBank is Token
# {
#     uint public MinDeposit;
#     mapping (address => uint) public Holders;
#
#      ///Constructor
#     function initTokenBank()
#     public
#     {
#         owner = msg.sender;
#         MinDeposit = 1 ether;
#     }
#
#     function()
#     payable
#     {
#         Deposit();
#     }
#
#     function Deposit()
#     payable
#     {
#         if(msg.value>MinDeposit)
#         {
#             Holders[msg.sender]+=msg.value;
#         }
#     }
#
#     function WitdrawTokenToHolder(address _to,address _token,uint _amount)
#     public
#     onlyOwner
#     {
#         if(Holders[_to]>0)
#         {
#             Holders[_to]=0;
#             WithdrawToken(_token,_amount,_to);
#         }
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[_addr]>0)
#         {
#             if(_addr.call.value(_wei)())
#             {
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
# }
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 93] Evaluation Results:
# Inserted Require: require(_wei<=Holders[_addr]);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 44
#  */
#
# pragma solidity ^0.4.19;
#
# contract Ownable
# {
#     address newOwner;
#     address owner = msg.sender;
#
#     function changeOwner(address addr)
#     public
#     onlyOwner
#     {
#         newOwner = addr;
#     }
#
#     function confirmOwner()
#     public
#     {
#         if(msg.sender==newOwner)
#         {
#             owner=newOwner;
#         }
#     }
#
#     modifier onlyOwner
#     {
#         if(owner == msg.sender)_;
#     }
# }
#
# contract Token is Ownable
# {
#     address owner = msg.sender;
#     function WithdrawToken(address token, uint256 amount,address to)
#     public
#     onlyOwner
#     {
#
#         token.call(bytes4(sha3("transfer(address,uint256)")),to,amount);
#     }
# }
#
# contract TokenBank is Token
# {
#     uint public MinDeposit;
#     mapping (address => uint) public Holders;
#
#      ///Constructor
#     function initTokenBank()
#     public
#     {
#         owner = msg.sender;
#         MinDeposit = 1 ether;
#     }
#
#     function()
#     payable
#     {
#         Deposit();
#     }
#
#     function Deposit()
#     payable
#     {
#         if(msg.value>MinDeposit)
#         {
#             Holders[msg.sender]+=msg.value;
#         }
#     }
#
#     function WitdrawTokenToHolder(address _to,address _token,uint _amount)
#     public
#     onlyOwner
#     {
#         if(Holders[_to]>0)
#         {
#             Holders[_to]=0;
#             WithdrawToken(_token,_amount,_to);
#         }
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#         if(Holders[_addr]>0)
#         {
#             if(_addr.call.value(_wei)())
#             {
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
# }
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92,99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92,93,99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 92,93] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 93,99] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>amount);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 25
#  */
#
# pragma solidity ^0.4.23;
#
# /*
# !!! THIS CONTRACT IS EXPLOITABLE AND FOR EDUCATIONAL PURPOSES ONLY !!!
#
# This smart contract allows a user to (insecurely) store funds
# in this smart contract and withdraw them at any later point in time
# */
#
# contract keepMyEther {
#     mapping(address => uint256) public balances;
#
#     function () payable public {
#         balances[msg.sender] += msg.value;
#     }
#
#     function withdraw() public {
# require(balances[msg.sender]>0);
#
#         msg.sender.call.value(balances[msg.sender])();
#         balances[msg.sender] = 0;
#     }
# }
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,24,27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,24] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: 0xb7c5c5aa4d42967efe906e1b66cb8df9cebf04f7.sol ===
#
# [Patch on line 24,27] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
# === Evaluating patches for contract: 0x8fd1e427396ddb511533cf9abdbebd0a7e08da35.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
# /*
#  * @source: etherscan.io
#  * @author: -
#  * @vulnerable_at_lines: 44,97
#  */
#
# pragma solidity ^0.4.18;
#
# contract Ownable
# {
#     address newOwner;
#     address owner = msg.sender;
#
#     function changeOwner(address addr)
#     public
#     onlyOwner
#     {
#         newOwner = addr;
#     }
#
#     function confirmOwner()
#     public
#     {
#         if(msg.sender==newOwner)
#         {
#             owner=newOwner;
#         }
#     }
#
#     modifier onlyOwner
#     {
#         if(owner == msg.sender)_;
#     }
# }
#
# contract Token is Ownable
# {
#     address owner = msg.sender;
#     function WithdrawToken(address token, uint256 amount,address to)
#     public
#     onlyOwner
#     {
# require(token.call(bytes4(sha3("balanceOf(address)")),(address)this)>=amount));
#
#         token.call(bytes4(sha3("transfer(address,uint256)")),to,amount);
#     }
# }
#
# contract TokenBank is Token
# {
#     uint public MinDeposit;
#     mapping (address => uint) public Holders;
#
#      ///Constructor
#     function initTokenBank()
#     public
#     {
#         owner = msg.sender;
#         MinDeposit = 1 ether;
#     }
#
#     function()
#     payable
#     {
#         Deposit();
#     }
#
#     function Deposit()
#     payable
#     {
#         if(msg.value>=MinDeposit)
#         {
#             Holders[msg.sender]+=msg.value;
#         }
#     }
#
#     function WitdrawTokenToHolder(address _to,address _token,uint _amount)
#     public
#     onlyOwner
#     {
#         if(Holders[_to]>0)
#         {
#             Holders[_to]=0;
#             WithdrawToken(_token,_amount,_to);
#         }
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
#
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#     function Bal() public constant returns(uint){return this.balance;}
# }
#
# ...
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47,47,49] Evaluation Results:
# Inserted Require: require(input<count);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47,47] Evaluation Results:
# Inserted Require: require(input<count);
#
# === Evaluating patches for contract: overflow_single_tx.sol ===
#
# [Patch on line 47,49] Evaluation Results:
# Inserted Require: require(input<count);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(count<10);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(count<10);
# /*
#  * @source: https://github.com/ConsenSys/evm-analyzer-benchmark-suite/blob/master/benchmarks/integer_overflow_add.sol
#  * @author: -
#  * @vulnerable_at_lines: 17
#  */
#
# //Single transaction overflow
# //Post-transaction effect: overflow escapes to publicly-readable storage
#
# pragma solidity ^0.4.19;
#
# contract IntegerOverflowAdd {
#     uint public count = 1;
#
#     function run(uint256 input) public {
# require(count<10);
#
#         count += input;
#     }
# }
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 18] Evaluation Results:
# Inserted Require: require(count<10);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,18] Evaluation Results:
# Inserted Require: require(count<10);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,16,18] Evaluation Results:
# Inserted Require: require(count<10);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,16] Evaluation Results:
# Inserted Require: require(count<10);
#
# === Evaluating patches for contract: integer_overflow_add.sol ===
#
# [Patch on line 16,18] Evaluation Results:
# Inserted Require: require(count<10);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(count>=input);
# /*
#  * @source: https://github.com/ConsenSys/evm-analyzer-benchmark-suite
#  * @author: Suhabe Bugrara
#  * @vulnerable_at_lines: 22
#  */
#
# //Multi-transactional, single function
# //Arithmetic instruction reachable
#
# pragma solidity ^0.4.23;
#
# contract IntegerOverflowMultiTxOneFuncFeasible {
#     uint256 private initialized = 0;
#     uint256 public count = 1;
#
#     function run(uint256 input) public {
# require(count>=input);
#         if (initialized == 0) {
#             initialized = 1;
#             return;
#         }
#
#         count -= input;
#     }
# }
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 23] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17,23] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17,21,23] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 17,21] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_onefunc_feasible.sol ===
#
# [Patch on line 21,23] Evaluation Results:
# Inserted Require: require(count>=input);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
# /*
#  * @source: https://github.com/sigp/solidity-security-blog
#  * @author: -
#  * @vulnerable_at_lines: 22
#  */
#
# //added pragma version
#  pragma solidity ^0.4.10;
#
#  contract TimeLock {
#
#      mapping(address => uint) public balances;
#      mapping(address => uint) public lockTime;
#
#      function deposit() public payable {
#          balances[msg.sender] += msg.value;
#          lockTime[msg.sender] = now + 1 weeks;
#      }
#
#      function increaseLockTime(uint _secondsToIncrease) public {
# require(balances[msg.sender]>0);
#
#          lockTime[msg.sender] += _secondsToIncrease;
#      }
#
#      function withdraw() public {
#          require(balances[msg.sender] > 0);
#          require(now > lockTime[msg.sender]);
#          uint transferValue = balances[msg.sender];
#          balances[msg.sender] = 0;
#          msg.sender.transfer(transferValue);
#      }
#  }
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,21,23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,21] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
#
# === Evaluating patches for contract: timelock.sol ===
#
# [Patch on line 21,23] Evaluation Results:
# Inserted Require: require(balances[msg.sender]>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(count>=input);
# /*
#  * @source: https://github.com/ConsenSys/evm-analyzer-benchmark-suite
#  * @author: Suhabe Bugrara
#  * @vulnerable_at_lines: 25
#  */
#
# //Multi-transactional, multi-function
# //Arithmetic instruction reachable
#
# pragma solidity ^0.4.23;
#
# contract IntegerOverflowMultiTxMultiFuncFeasible {
#     uint256 private initialized = 0;
#     uint256 public count = 1;
#
#     function init() public {
#         initialized = 1;
#     }
#
#     function run(uint256 input) {
# require(count>=input);
#         if (initialized == 0) {
#             return;
#         }
#
#         count -= input;
#     }
# }
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 26] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21,26] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21,24,26] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 21,24] Evaluation Results:
# Inserted Require: require(count>=input);
#
# === Evaluating patches for contract: integer_overflow_multitx_multifunc_feasible.sol ===
#
# [Patch on line 24,26] Evaluation Results:
# Inserted Require: require(count>=input);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 42] Evaluation Results:
# Inserted Require: require(pot>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34] Evaluation Results:
# Inserted Require: require(pot>0);
# /*
#  * @article: https://blog.positive.com/predicting-random-numbers-in-ethereum-smart-contracts-e5358c6b8620
#  * @source: https://etherscan.io/address/0xa11e4ed59dc94e69612f3111942626ed513cb172#code
#  * @vulnerable_at_lines: 43
#  * @author: -
#  */
#
#  pragma solidity ^0.4.15;
#
# /// @title Ethereum Lottery Game.
#
# contract EtherLotto {
#
#     // Amount of ether needed for participating in the lottery.
#     uint constant TICKET_AMOUNT = 10;
#
#     // Fixed amount fee for each lottery game.
#     uint constant FEE_AMOUNT = 1;
#
#     // Address where fee is sent.
#     address public bank;
#
#     // Public jackpot that each participant can win (minus fee).
#     uint public pot;
#
#     // Lottery constructor sets bank account from the smart-contract owner.
#     function EtherLotto() {
#         bank = msg.sender;
#     }
#
#     // Public function for playing lottery. Each time this function
#     // is invoked, the sender has an oportunity for winning pot.
#     function play() payable {
# require(pot>0);
#
#         // Participants must spend some fixed ether before playing lottery.
#         assert(msg.value == TICKET_AMOUNT);
#
#         // Increase pot for each participant.
#         pot += msg.value;
#
#         // Compute some *almost random* value for selecting winner from current transaction.
#
#         var random = uint(sha3(block.timestamp)) % 2;
#
#         // Distribution: 50% of participants will be winners.
#         if (random == 0) {
#
#             // Send fee to bank account.
#             bank.transfer(FEE_AMOUNT);
#
#             // Send jackpot to winner.
#             msg.sender.transfer(pot - FEE_AMOUNT);
#
#             // Restart jackpot.
#             pot = 0;
#         }
#     }
#
# }
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 57] Evaluation Results:
# Inserted Require: require(pot>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,57] Evaluation Results:
# Inserted Require: require(pot>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,42,57] Evaluation Results:
# Inserted Require: require(pot>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,42] Evaluation Results:
# Inserted Require: require(pot>0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 42,57] Evaluation Results:
# Inserted Require: require(pot>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(block.timestamp<=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(block.timestamp<=1546300800);
# /*
#  * @source: https://github.com/SmartContractSecurity/SWC-registry/blob/master/test_cases/timestamp_dependence/timed_crowdsale.sol
#  * @author: -
#  * @vulnerable_at_lines: 13
#  */
#
# pragma solidity ^0.4.25;
#
# contract TimedCrowdsale {
#   // Sale should finish exactly at January 1, 2019
#   function isSaleFinished() view public returns (bool) {
# require(block.timestamp<=1546300800);
#
#     return block.timestamp >= 1546300800;
#   }
# }
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 14] Evaluation Results:
# Inserted Require: require(block.timestamp<=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,14] Evaluation Results:
# Inserted Require: require(block.timestamp<=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,12,14] Evaluation Results:
# Inserted Require: require(block.timestamp<=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,12] Evaluation Results:
# Inserted Require: require(block.timestamp<=1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,14] Evaluation Results:
# Inserted Require: require(block.timestamp<=1546300800);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# /*
#  * @source: https://github.com/sigp/solidity-security-blog
#  * @author: -
#  * @vulnerable_at_lines: 18,20
#  */
#
# pragma solidity ^0.4.25;
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.sender==tx.origin);
#         require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
# }
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,17,24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,17] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 17,24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# /*
#  * @source: https://github.com/sigp/solidity-security-blog
#  * @author: -
#  * @vulnerable_at_lines: 18,20
#  */
#
# pragma solidity ^0.4.25;
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.sender==tx.origin);
#         require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
# }
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,19,24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,19] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 19,24] Evaluation Results:
# Inserted Require: require(msg.sender==tx.origin);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/validation_results_100K.csv' (Excel-friendly format).
