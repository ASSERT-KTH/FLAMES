# %% [markdown]
# # Training

# %% [markdown]
# ### Load Dataset

# %%
import os
from datasets import load_from_disk, load_dataset, concatenate_datasets
#dataset_train = load_dataset('ASSERT-KTH/DISL', 'invariants-infillings', cache_dir=os.environ.get('TMPDIR'), streaming=True, split='train')
#dataset_test = load_dataset('ASSERT-KTH/DISL', 'invariants-infillings', cache_dir=os.environ.get('TMPDIR'), streaming=True, split='test')

dataset = load_dataset('GGmorello/FLAMES', 'abstract', num_proc=10)['train']

# %%
dataset['label']
# Out:
# ['_impl!=address(0)',
#  '_implementation!=implementation',
#  'msg.sender==proxyOwner()',
#  'newOwner!=address(0)',
#  'address(this).delegatecall(data)',
#  'initialImplementation.delegatecall(calldata)',
#  '_masterCopy!=address(0),"Invalid master copy address provided"',
#  "success&&(data.length==0||abi.decode(data,(bool))),'TransferHelper::safeApprove: approve failed'",
#  "success&&(data.length==0||abi.decode(data,(bool))),'TransferHelper::safeTransfer: transfer failed'",
#  "success&&(data.length==0||abi.decode(data,(bool))),'TransferHelper::transferFrom: transferFrom failed'",
#  "success,'TransferHelper::safeTransferETH: ETH transfer failed'",
#  "success,'Flush failed'",
#  "msg.sender==parentAddress,'Only Parent'",
#  "parentAddress==address(0x0),'Already initialized'",
#  "success,'Flush failed'",
#  'isAuthorized(msg.sender,msg.sig)',
#  'setCache(_cacheAddr)',
#  '_target!=0x0',
#  '_cacheAddr!=0x0',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,errorMessage',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,errorMessage',
#  'b!=0,errorMessage',
#  '_owner==_msgSender(),"Ownable: caller is not the owner"',
#  '_isAdmin[_msgSender()]==true,"Ownable: caller is not the administrator"',
#  'newOwner!=address(0),"Ownable: new owner is the zero address"',
#  '_isAdmin[newAdmin]==false,"Ownable: address is already admin"',
#  'newAdmin!=address(0),"Ownable: new admin is the zero address"',
#  '_isAdmin[oldAdmin]==true,"Ownable: address is not admin"',
#  'oldAdmin!=address(0),"Ownable: old admin is the zero address"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  '_blacklist[sender]==false,"ERC20: sender address "',
#  'account!=address(0),"ERC20: mint to the zero address"',
#  'account!=address(0),"ERC20: Can\'t lock zero address"',
#  '_balances[account]>=sys.amountToken.add(amountLock),"ERC20: You can\'t lock more than account balances"',
#  'account!=address(0),"ERC20: Can\'t lock zero address"',
#  'account!=address(0),"ERC20: Can\'t blacklist zero address"',
#  '_blacklist[account]==false,"ERC20: Address already in blacklist"',
#  'account!=address(0),"ERC20: Can\'t blacklist zero address"',
#  '_blacklist[account]==true,"ERC20: Address not blacklisted"',
#  'account!=address(0),"ERC20: burn from the zero address"',
#  'funder!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'IERC20(token).balanceOf(address(this))>=_locks[lockID].balance,"UniversalVaultV2: insufficient balance"',
#  'address(tokenId)!=address(this),"can\'t self lock"',
#  'IERC721(token).ownerOf(tokenId)==address(this),"UniversalVaultV2: vault not owner of nft"',
#  '!_lockedERC721s[token].contains(tokenId),"NFT already locked"',
#  '_lockSet.contains(lockID),"UniversalVaultV2: missing lock"',
#  'IERC721(token).ownerOf(tokenId)==address(this),"UniversalVaultV2: vault not owner of nft"',
#  '_lockedERC721s[token].contains(tokenId),"NFT not locked"',
#  '_lockSet.contains(lockID),"UniversalVaultV2: missing lock"',
#  '_lockSet.contains(lockID),"UniversalVaultV2: missing lock"',
#  'gasleft()>=RAGEQUIT_GAS,"UniversalVaultV2: insufficient gas"',
#  'IERC20(token).balanceOf(address(this))>=getBalanceLocked(token).add(amount),"UniversalVaultV2: insufficient balance"',
#  'IERC721(token).ownerOf(tokenId)==address(this),"UniversalVaultV2: vault not owner of nft"',
#  '!_lockedERC721s[token].contains(tokenId),"NFT is locked. Unlock first."',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,"SafeMath: subtraction overflow"',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,"SafeMath: division by zero"',
#  'b>0,"SafeMath: modulo by zero"',
#  'b<=a,errorMessage',
#  'b>0,errorMessage',
#  'b>0,errorMessage',
#  'owner!=address(0),"ERC721: balance query for the zero address"',
#  '_exists(tokenId),"ERC721Metadata: URI query for nonexistent token"',
#  'to!=owner,"ERC721: approval to current owner"',
#  '_msgSender()==owner||ERC721.isApprovedForAll(owner,_msgSender()),"ERC721: approve caller is not owner nor approved for all"',
#  '_exists(tokenId),"ERC721: approved query for nonexistent token"',
#  'operator!=_msgSender(),"ERC721: approve to caller"',
#  '_isApprovedOrOwner(_msgSender(),tokenId),"ERC721: transfer caller is not owner nor approved"',
#  '_isApprovedOrOwner(_msgSender(),tokenId),"ERC721: transfer caller is not owner nor approved"',
#  '_checkOnERC721Received(from,to,tokenId,_data),"ERC721: transfer to non ERC721Receiver implementer"',
#  '_exists(tokenId),"ERC721: operator query for nonexistent token"',
#  '_checkOnERC721Received(address(0),to,tokenId,_data),"ERC721: transfer to non ERC721Receiver implementer"',
#  'to!=address(0),"ERC721: mint to the zero address"',
#  '!_exists(tokenId),"ERC721: token already minted"',
#  'ERC721.ownerOf(tokenId)==from,"ERC721: transfer of token that is not own"',
#  'to!=address(0),"ERC721: transfer to the zero address"',
#  '_exists(tokenId),"ERC721Metadata: URI set of nonexistent token"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  'isValidSignature(permissionHash,signature)==VALID_SIG,"ERC1271: Invalid signature"',
#  'owner()==msg.sender,"OwnableByERC721: caller is not the owner"',
#  'msg.sender==admin,"not allowed"',
#  'newAdmin!=address(0),"new admin can\'t the zero address"',
#  '_bonusTokenSet.contains(token)||token==rewardToken,"cannot fund with unrecognized token"',
#  'isValidAddress(recipient),"invalid recipient"',
#  '_vaultFactorySet.add(factory),"UniStakerV2: vault factory already registered"',
#  '_vaultFactorySet.remove(factory),"UniStakerV2: vault factory not registered"',
#  'isValidAddress(bonusToken),"invalid bonus token address or is already present"',
#  '_bonusTokenSet.length()<MAX_BONUS_TOKENS,"UniStakerV2: max bonus tokens reached "',
#  '_bonusTokenSet.remove(bonusToken),"UniStakerV2: bonus token not present "',
#  'rewardCalcTemplates[name]==address(0),"Template already exists"',
#  'rewardCalcTemplates[name]!=address(0),"Template does not exist"',
#  'lmRewards[token].startedAt==0,"A reward program already live for this token"',
#  'rewardCalcTemplates[rewardCalcTemplateName]!=address(0),"Reward Calculator Template does not exist"',
#  'lmRewards[token].startedAt!=0,"No reward program currently live for this token"',
#  'lmRewards[token].startedAt!=0,"No reward program currently live for this token"',
#  'lmRewards[lmToken].startedAt!=0,"No reward program currently live for this LM token"',
#  '_bonusTokenSet.contains(bonusToken),"Bonus token not registered"',
#  '_vaultSet.contains(msg.sender),"UniStakerV2: no vault"',
#  'vaultTokens.length()>0,"UniStakerV2: no stake"',
#  'isValidVault(vault,vaultFactory),"UniStakerV2: vault is not valid"',
#  'vaultData.tokens.length()<MAX_TOKENS_STAKED_PER_VAULT,"UniStakerV2: MAX_TOKENS_STAKED_PER_VAULT reached"',
#  '_vaultSet.contains(vault),"UniStakerV2: no vault"',
#  'isValidAddress(recipient),"UniStakerV2: invalid recipient"',
#  'vaultData.tokens.contains(token),"UniStakerV2: no token in vault"',
#  'vaultData.tokenStake[token]>=1,"UniStakerV2: insufficient vault token stake"',
#  'stakedTokenTotal[token]>=1,"stakedTokenTotal[token] is less than 1"',
#  'numVests<=vestingLMRewards[msg.sender][token].length,"num vests can\'t be greater than available vests"',
#  'templates[name]==address(0),"Template already exists"',
#  'templates[name]!=address(0),"Template does not exist"',
#  'msg.sender==Powered.getPowerController(),"RewardPool: only controller can withdraw after shutdown"',
#  'recipient!=address(0),"RewardPool: recipient not defined"',
#  'isOnline(),"Powered: is not online"',
#  'isOffline(),"Powered: is not offline"',
#  '!isShutdown(),"Powered: is shutdown"',
#  'isShutdown(),"Powered: is not shutdown"',
#  'success,string(err)',
#  'success,string(err)',
#  'msg.sender==newOwner',
#  'msg.sender==ownerWallet',
#  "!userInfos[_user].joined,'User exists'",
#  "msg.value==priceOfLevel[1],'Incorrect Value'",
#  "msg.sender==_user,'Invalid user'",
#  "userInfos[_user].joined,'User not exist'",
#  "_level>0&&_level<9,'Incorrect level'",
#  "msg.value==priceOfLevel[_level],'Incorrect Value'",
#  "msg.sender==_user,'Invalid user'",
#  "userInfos[_user].levelExpired[l]>=now,'Buy the previous level first'",
#  "!noFreeReferrer,'No Free Referrer'",
#  '_user.length<=50,"invalid input"',
#  'regUser(_user[i],1),"registration fail"',
#  'value==0,"Strings: hex len insufficient"',
#  'b<=a,errorMessage',
#  'b>0,errorMessage',
#  'b>0,errorMessage',
#  'address(this).balance>=amount',
#  'success',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  '!paused()',
#  'paused()',
#  'owner()==_msgSender()',
#  'newOwner!=address(0)',
#  '_royalties[i].account!=address(0x0)',
#  '_royalties[i].value!=0',
#  'totalValue<10000',
#  '!inited',
#  'verify(userAddress,metaTx,sigR,sigS,sigV)',
#  'success',
#  'signer!=address(0)',
#  'owner!=address(0)',
#  'owner!=address(0)',
#  '_exists(tokenId)',
#  'to!=owner',
#  '_msgSender()==owner||isApprovedForAll(owner,_msgSender())',
#  '_exists(tokenId)',
#  'operator!=_msgSender()',
#  '_isApprovedOrOwner(_msgSender(),tokenId)',
#  '_isApprovedOrOwner(_msgSender(),tokenId)',
#  '_checkOnERC721Received(from,to,tokenId,_data)',
#  '_exists(tokenId)',
#  '_checkOnERC721Received(address(0),to,tokenId,_data)',
#  'to!=address(0)',
#  '!_exists(tokenId)',
#  'ERC721.ownerOf(tokenId)==from',
#  'to!=address(0)',
#  'index<ERC721.balanceOf(owner)',
#  'index<ERC721Enumerable.totalSupply()',
#  'msgSender()==owner()||operators[msgSender()]',
#  '_names.length==baseURIs.length',
#  '_names.length==_starts.length',
#  '_names.length==_supplys.length',
#  'collection<collections.length',
#  'collection<collections.length',
#  'collections[collection].supply==250',
#  'pointer<coll.supply',
#  'collection<collections.length',
#  'collection<collections.length',
#  'collection<collections.length',
#  '_exists(_tokenId)',
#  'collectionId<collections.length',
#  '_isApprovedOrOwner(_msgSender(),tokenId)',
#  '_exists(_tokenId)',
#  '_collectionId<collections.length',
#  '_exists(tokenId)',
#  'msg.sender==owner',
#  'this.balance>0',
#  'bal>0',
#  '_masterCopy!=0,"Invalid master copy address provided"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  'success,"Transfer failed."',
#  'merkleRoot!=0,"No address is eligible for presale minting yet"',
#  'firstPresaleOpen,"First Presale is not open yet"',
#  'totalSupply()+_count<=500,"Purchase will exceed NFTs alloted for first presale"',
#  'MerkleProof.verify(_proof,merkleRoot,keccak256(abi.encodePacked(_to))),"Address not eligible for first presale mint"',
#  '_count>0&&_count<=2,"Minimum 1 & Maximum 2 Ocean World can be minted per transaction"',
#  'msg.value>=firstPresalePrice*_count,"Ether sent with this transaction is not correct"',
#  'totalSupply()+_count<=9500,"Exceeds maximum supply of Ocean World"',
#  '_count>0,"Minimum 1 Ocean World has to be minted per transaction"',
#  'secondPresaleOpen||thirdPresaleOpen,"Second or third presale is not live yet"',
#  '_count<=2,"Maximum 2 Ocean World can be minted per transaction"',
#  'msg.value>=secondAndThirdPresalePrice*_count,"Ether sent with this transaction is not correct"',
#  'totalSupply()+_count<=9500,"Exceeds maximum supply of Ocean World"',
#  'totalSupply()+_count<=5000,"Exceeds maximum supply of Ocean World"',
#  'totalSupply()+_count<=MAX_OW,"Exceeds maximum supply of Ocean World"',
#  '_count>0,"Minimum 1 Ocean World has to be minted per transaction"',
#  'saleOpen,"Sale is not open yet"',
#  '_count<=2,"Maximum 2 Ocean World can be minted per transaction"',
#  'msg.value>=price*_count,"Ether sent with this transaction is not correct"',
#  'msg.sender==owner,"CollectionContract: Caller is not owner"',
#  'collectionFactory.rolesContract().isOperator(msg.sender),"CollectionContract: Caller is not an operator"',
#  '_collectionFactory.isContract(),"CollectionContract: collectionFactory is not a contract"',
#  'msg.sender==address(collectionFactory),"CollectionContract: Collection must be created via the factory"',
#  'tokenCreatorPaymentAddress!=address(0),"CollectionContract: tokenCreatorPaymentAddress is required"',
#  '_maxTokenId>0,"CollectionContract: Max token ID may not be cleared"',
#  'maxTokenId==0||_maxTokenId<maxTokenId,"CollectionContract: Max token ID may not increase"',
#  'latestTokenId+1<=_maxTokenId,"CollectionContract: Max token ID must be greater than last mint"',
#  'totalSupply()==0,"CollectionContract: Any NFTs minted must be burned first"',
#  'Address.requireAuthorizedAccountMigration(newAddress,signature',
#  'Address.requireAuthorizedAccountMigration(newAddress,signature',
#  '_exists(tokenId),"CollectionContract: URI query for nonexistent token"',
#  'bytes(tokenCID).length>0,"CollectionContract: tokenCID is required"',
#  '!cidToMinted[tokenCID],"CollectionContract: NFT was already minted"',
#  'maxTokenId==0||tokenId<=maxTokenId,"CollectionContract: Max token count has already been minted"',
#  'tokenIdToCreatorPaymentAddress[tokenId]==originalPaymentAddress,"CollectionContract: Payment address is not the expected value"',
#  'originalAddress!=newAddress,"AccountMigration: Cannot migrate to the same account"',
#  'originalAddress.isValidSignatureNow(hash,signature),"AccountMigration: Signature must be from the original account"',
#  'data[dataLocation]==expectedData[i],"Bytes: Data provided does not include the expectedAddress"',
#  '_initializing?_isConstructor():!_initialized,"Initializable: contract is already initialized"',
#  '_initializing,"Initializable: contract is not initializing"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  'value==0,"Strings: hex length insufficient"',
#  'owner!=address(0),"ERC721: balance query for the zero address"',
#  'owner!=address(0),"ERC721: owner query for nonexistent token"',
#  '_exists(tokenId),"ERC721Metadata: URI query for nonexistent token"',
#  'to!=owner,"ERC721: approval to current owner"',
#  '_msgSender()==owner||isApprovedForAll(owner,_msgSender()),"ERC721: approve caller is not owner nor approved for all"',
#  '_exists(tokenId),"ERC721: approved query for nonexistent token"',
#  'operator!=_msgSender(),"ERC721: approve to caller"',
#  '_isApprovedOrOwner(_msgSender(),tokenId),"ERC721: transfer caller is not owner nor approved"',
#  '_isApprovedOrOwner(_msgSender(),tokenId),"ERC721: transfer caller is not owner nor approved"',
#  '_checkOnERC721Received(from,to,tokenId,_data),"ERC721: transfer to non ERC721Receiver implementer"',
#  '_exists(tokenId),"ERC721: operator query for nonexistent token"',
#  '_checkOnERC721Received(address(0),to,tokenId,_data),"ERC721: transfer to non ERC721Receiver implementer"',
#  'to!=address(0),"ERC721: mint to the zero address"',
#  '!_exists(tokenId),"ERC721: token already minted"',
#  'ERC721.ownerOf(tokenId)==from,"ERC721: transfer of token that is not own"',
#  'to!=address(0),"ERC721: transfer to the zero address"',
#  'owner()==_msgSender(),"Ownable: caller is not the owner"',
#  'newOwner!=address(0),"Ownable: new owner is the zero address"',
#  'payees.length==shares_.length,"PaymentSplitter: payees and shares length mismatch"',
#  'payees.length>0,"PaymentSplitter: no payees"',
#  '_shares[account]>0,"PaymentSplitter: account has no shares"',
#  'payment!=0,"PaymentSplitter: account is not due payment"',
#  'account!=address(0),"PaymentSplitter: account is the zero address"',
#  'shares_>0,"PaymentSplitter: shares are 0"',
#  '_shares[account]==0,"PaymentSplitter: account already has shares"',
#  'active,"INACTIVE"',
#  'mintQty==1,"JUST ONE"',
#  'msg.value==0,"FREE"',
#  '!free[msg.sender],"PAY"',
#  'totalSupply+mintQty<=MAXQTY,"TOO MUCH"',
#  'mintMap[msg.sender]+mintQty<=LIMIT,"YOU ARE DONE"',
#  'msg.value>=FEE*mintQty,"NOT ENOUGH"',
#  '_exists(_tokenId),"ERC721Metadata: Nonexistent token"',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,errorMessage',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,errorMessage',
#  'b!=0,errorMessage',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  '_owner==_msgSender(),"Ownable: caller is not the owner"',
#  'newOwner!=address(0),"Ownable: new owner is the zero address"',
#  '!_isExcluded[sender],"Excluded addresses cannot call this function"',
#  'tAmount<=_tTotal,"Amount must be less than supply"',
#  'rAmount<=_rTotal,"Amount must be less than total reflections"',
#  '!_isExcluded[account],"Account is already excluded"',
#  '_isExcluded[account],"Account is already included"',
#  'owner!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  'amount>0,"Transfer amount must be greater than zero"',
#  'c/a==b',
#  'b>0',
#  'b<=a',
#  'c>=a',
#  'b!=0',
#  'owner!=address(0)',
#  'owner!=address(0)',
#  'to!=owner',
#  'msg.sender==owner||isApprovedForAll(owner,msg.sender)',
#  '_exists(tokenId)',
#  'to!=msg.sender',
#  '_isApprovedOrOwner(msg.sender,tokenId)',
#  '_checkOnERC721Received(from,to,tokenId,_data)',
#  'to!=address(0)',
#  '!_exists(tokenId)',
#  'ownerOf(tokenId)==owner',
#  'ownerOf(tokenId)==from',
#  'to!=address(0)',
#  'index<balanceOf(owner)',
#  'index<totalSupply()',
#  'isOwner()',
#  'newOwner!=address(0)',
#  'msg.sender==owner',
#  '_to!=address(0)',
#  '_amount<=balances[msg.sender]',
#  '_to!=address(0)',
#  '_amount<=balances[_from]',
#  '_amount<=allowed[_from][msg.sender]',
#  '_value<=balances[msg.sender]',
#  '_spender.call(bytes4(bytes32(keccak256("receiveApproval(address,uint256,address,bytes)"))),msg.sender,_value,this,_extraData)',
#  'ed=_require',
#  'ed=_newRequire',
#  'yetNeeded=m_require',
#  'isOwner(),"Ownable: caller is not the owner"',
#  'newOwner!=address(0),"Ownable: new owner is the zero address"',
#  'block.timestamp>=boostStarttime[msg.sender]+1hours,"already boost"',
#  'block.timestamp>=starttime,"not start"',
#  'amount>0,"Cannot stake 0"',
#  'amount>0,"Cannot withdraw 0"',
#  'msg.value==boostCost,"Wrong cost"',
#  'msg.value==boostCost,"Wrong cost"',
#  'msg.value==boostCost,"Wrong cost"',
#  'msg.value==boostCost,"Wrong cost"',
#  'msg.sender==recoveryAddress,"sender must be recovery address"',
#  '!initialized,"must not already be initialized"',
#  'msg.sender==address(this),"must be called from `invoke()`"',
#  '_authorizedAddress!=_recoveryAddress,"Do not use the recovery address as an authorized address."',
#  'address(_cosigner)!=_recoveryAddress,"Do not use the recovery address as a cosigner."',
#  '_authorizedAddress!=address(0),"Authorized addresses must not be zero."',
#  'address(_cosigner)!=address(0),"Initial cosigner must not be zero."',
#  'msg.data.length==0,"Invalid transaction."',
#  '_authorizedAddress!=address(0),"Authorized addresses must not be zero."',
#  '_authorizedAddress!=recoveryAddress,"Do not use the recovery address as an authorized address."',
#  'address(_cosigner)==address(0)||address(_cosigner)!=recoveryAddress,"Do not use the recovery address as a cosigner."',
#  '_authorizedAddress!=address(0),"Authorized addresses must not be zero."',
#  '_authorizedAddress!=recoveryAddress,"Do not use the recovery address as an authorized address."',
#  'address(_cosigner)!=address(0),"The cosigner must not be zero."',
#  'address(authorizations[authVersion+uint256(_recoveryAddress)])==address(0),"Do not use an authorized address as the recovery address."',
#  '_version>0&&_version<0xffffffff,"Invalid version number."',
#  'shiftedVersion<authVersion,"You can only recover gas from expired authVersions."',
#  'address(authorizations[authVersion+uint256(msg.sender)])==msg.sender,"Invalid authorization."',
#  'v==27||v==28,"Invalid signature version."',
#  'signer!=address(0),"Invalid signature."',
#  'nonce==nonces[signer],"must use correct nonce"',
#  'signer==authorizedAddress,"authorized addresses must be equal"',
#  'requiredCosigner==signer||requiredCosigner==msg.sender,"Invalid authorization."',
#  'v==27||v==28,"Invalid signature version."',
#  'cosigner!=address(0),"Invalid signature."',
#  'requiredCosigner==cosigner||requiredCosigner==msg.sender,"Invalid authorization."',
#  'v[0]==27||v[0]==28,"invalid signature version v[0]"',
#  'v[1]==27||v[1]==28,"invalid signature version v[1]"',
#  'signer!=address(0),"Invalid signature for signer."',
#  'cosigner!=address(0),"Invalid signature for cosigner."',
#  'signer==authorizedAddress,"authorized addresses must be equal"',
#  'nonce==nonces[signer],"must use correct nonce for signer"',
#  'requiredCosigner==signer||requiredCosigner==cosigner,"Invalid authorization."',
#  'data.length>=85,invalidLengthMessage',
#  'auth[msg.sender],"not-self"',
#  'shield!=_shield,"shield is set"',
#  'msg.sender==address(this)||msg.sender==instaIndex,"not-self-index"',
#  'user!=address(0),"not-valid"',
#  '!auth[user],"already-enabled"',
#  'msg.sender==address(this),"not-self"',
#  'user!=address(0),"not-valid"',
#  'auth[user],"already-disabled"',
#  '_target!=address(0),"target-invalid"',
#  'isAuth(msg.sender)||msg.sender==instaIndex,"permission-denied"',
#  '_targets.length==_datas.length,"array-length-invalid"',
#  'ConnectorsInterface(indexContract.connectors(version)).isConnector(_targets),"not-connector"',
#  'ConnectorsInterface(indexContract.connectors(version)).isStaticConnector(_targets),"not-static-connector"',
#  'CheckInterface(_check).isOk(),"not-ok"',
#  'msg.sender==nodeAddress||msg.sender==withdrawalAddress,"Only the node operator can access this method"',
#  'address(_rocketStorageAddress)!=address(0x0),"Invalid storage address"',
#  'contractExists(delegateAddress),"Delegate contract does not exist"',
#  'rocketMinipoolDelegate!=rocketMinipoolDelegatePrev,"New delegate is the same as the existing one"',
#  'rocketMinipoolDelegatePrev!=address(0x0),"Previous delegate contract is not set"',
#  'contractExists(delegateContract),"Delegate contract does not exist"',
#  'contractAddress!=address(0x0),"Contract not found"',
#  'msg.sender==owner',
#  'newOwner!=address(0)',
#  '!isLocked',
#  'tokenBalance()>0',
#  'isLocked',
#  '!isReleased',
#  'lockOver()',
#  'c/a==b',
#  'b>0',
#  'b<=a',
#  'c>=a',
#  'b!=0',
#  'isOwner()',
#  'newOwner!=address(0)',
#  'logicAddr!=address(0),"logic-proxy-address-required"',
#  'RegistryInterface(registry).logic(logicAddr),"logic-not-authorised"',
#  'isAuth(msg.sender),"permission-denied"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  'owner==msg.sender',
#  'success,"Flush failed"',
#  'msg.sender==parentAddress,"Only Parent"',
#  'parentAddress==address(0x0),"Already initialized"',
#  'instance.transfer(parentAddress,forwarderBalance),"Token flush failed"',
#  'success,"Flush failed"',
#  'value<=_balances[msg.sender]',
#  'to!=address(0)',
#  'spender!=address(0)',
#  'value<=_balances[from]',
#  'value<=_allowed[from][msg.sender]',
#  'to!=address(0)',
#  'spender!=address(0)',
#  'spender!=address(0)',
#  'account!=address(0)',
#  'account!=address(0)',
#  'amount<=_balances[account]',
#  'amount<=_allowed[account][msg.sender]',
#  'c>=a',
#  'b<=a',
#  'a==0||c/a==b',
#  'b>0',
#  'isOwner(),"Ownable: caller is not the owner"',
#  'newOwner!=address(0),"Ownable: new owner is the zero address"',
#  '!has(role,account),"Roles: account already has role"',
#  'has(role,account),"Roles: account does not have role"',
#  'account!=address(0),"Roles: account is the zero address"',
#  'isSigner(_msgSender()),"SignerRole: caller does not have the Signer role"',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,errorMessage',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,errorMessage',
#  'b!=0,errorMessage',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'interfaceId!=0xffffffff,"ERC165: invalid interface id"',
#  'owner!=address(0),"ERC721: balance query for the zero address"',
#  'owner!=address(0),"ERC721: owner query for nonexistent token"',
#  'to!=owner,"ERC721: approval to current owner"',
#  '_msgSender()==owner||isApprovedForAll(owner,_msgSender()),"ERC721: approve caller is not owner nor approved for all"',
#  '_exists(tokenId),"ERC721: approved query for nonexistent token"',
#  'to!=_msgSender(),"ERC721: approve to caller"',
#  '_isApprovedOrOwner(_msgSender(),tokenId),"ERC721: transfer caller is not owner nor approved"',
#  '_isApprovedOrOwner(_msgSender(),tokenId),"ERC721: transfer caller is not owner nor approved"',
#  '_checkOnERC721Received(from,to,tokenId,_data),"ERC721: transfer to non ERC721Receiver implementer"',
#  '_exists(tokenId),"ERC721: operator query for nonexistent token"',
#  '_checkOnERC721Received(address(0),to,tokenId,_data),"ERC721: transfer to non ERC721Receiver implementer"',
#  'to!=address(0),"ERC721: mint to the zero address"',
#  '!_exists(tokenId),"ERC721: token already minted"',
#  'ownerOf(tokenId)==owner,"ERC721: burn of token that is not own"',
#  'ownerOf(tokenId)==from,"ERC721: transfer of token that is not own"',
#  'to!=address(0),"ERC721: transfer to the zero address"',
#  '_isApprovedOrOwner(_msgSender(),tokenId),"ERC721Burnable: caller is not owner nor approved"',
#  'index<balanceOf(owner),"ERC721Enumerable: owner index out of bounds"',
#  'index<totalSupply(),"ERC721Enumerable: global index out of bounds"',
#  '_fees[i].recipient!=address(0x0),"Recipient should be present"',
#  '_fees[i].value!=0,"Fee value should be positive"',
#  '_exists(tokenId),"ERC721Metadata: URI query for nonexistent token"',
#  '_exists(tokenId),"ERC721Metadata: URI set of nonexistent token"',
#  'isSigner(ecrecover(keccak256(abi.encodePacked(this,tokenId)),v,r,s)),"signer should sign tokenId"',
#  'now>=LOCK_START_TIME',
#  'now<=LOCK_END_TIME',
#  'target==addressFrom(parent,nonce)',
#  'isOwner()',
#  'newOwner!=address(0)',
#  '_to!=address(0)',
#  '_value>0',
#  'balanceOf[msg.sender]>=_value',
#  'balanceOf[_to]+_value>=balanceOf[_to]',
#  '(_value==0)||(allowance[msg.sender][_spender]==0)',
#  '_to!=address(0)',
#  '_value>0',
#  'balanceOf[_from]>=_value',
#  'balanceOf[_to]+_value>balanceOf[_to]',
#  '_value<=allowance[_from][msg.sender]',
#  '_to!=0x0',
#  'balanceOf[_from]>=_value',
#  'balanceOf[_to]+_value>=balanceOf[_to]',
#  '_value<=allowance[_from][msg.sender]',
#  'balanceOf[msg.sender]>=_value',
#  'balanceOf[_from]>=_value',
#  '_value<=allowance[_from][msg.sender]',
#  '!hasMemberSubmittedPublicKey(msg.sender),"Member already submitted a public key"',
#  '_publicKey.length==64,"Public key must be 64 bytes long"',
#  'publicKey.length!=0,"Public key was not set yet"',
#  '!isSigningInProgress(),"Signer is busy"',
#  'isSigningInProgress(),"Not awaiting a signature"',
#  '_recoveryID<4,"Recovery ID must be one of {0, 1, 2, 3}"',
#  'uint256(_s)<=0x7FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF5D576E7357A4501DDFE92F46681B20A0,"Malleable signature - s should be in the low half of secp256k1 curve\'s order"',
#  'publicKeyToAddress(publicKey)==ecrecover(digest,_v,_r,_s),"Invalid signature"',
#  'dividend>0,"Dividend value must be non-zero"',
#  'dividend>0,"Dividend value must be non-zero"',
#  'value>0,"No funds to withdraw"',
#  'success,"Transfer failed"',
#  'isFraud,"Signature is not fraudulent"',
#  'bondPerMember>0,"Partial signer bond must be non-zero"',
#  'publicKey.length!=0,"Public key was not set yet"',
#  '_signedDigest==calculatedDigest,"Signed digest does not match sha256 hash of the preimage"',
#  '!isInitialized,"Contract already initialized"',
#  'owner==msg.sender,"Caller is not the keep owner"',
#  'members.contains(msg.sender),"Caller is not the keep member"',
#  'isActive(),"Keep is not active"',
#  '_groupSize>0,"Minimum signing group size is 1"',
#  '_groupSize<=16,"Maximum signing group size is 16"',
#  '_honestThreshold>0,"Honest threshold must be greater than 0"',
#  '_honestThreshold<=_groupSize,"Honest threshold must be less or equal the group size"',
#  'memberBond>0,"Bond per member must be greater than zero"',
#  'msg.value>=openKeepFeeEstimate(),"Insufficient payment for opening a new keep"',
#  'index<keeps.length,"Out of bounds."',
#  'candidatesPools[_application]==address(0),"Sortition pool already exists"',
#  'candidatesPools[_application]!=address(0),"No pool found for the application"',
#  'isOperatorRegistered(_operator,_application),"Operator not registered for the application"',
#  'reseedPool>=beaconFee,"Not enough funds to trigger reseed"',
#  'address(randomBeacon)==msg.sender,"Caller is not the random beacon"',
#  '_minimumStake>0,"Minimum stake cannot be zero"',
#  'msg.sender==params.owner,"Only owner may select groups"',
#  'msg.sender==poolParams.owner,"Only owner may update minimum bond value"',
#  'isOperatorInPool(operator),"Operator is not in the pool"',
#  'eligibleWeight>0,"Operator not eligible"',
#  'eligibleWeight!=inPoolWeight,"Operator already up to date"',
#  '_truncatedRange>0,"Not enough operators in pool"',
#  '!isOperatorRegistered(operator),"Operator is already registered in the pool"',
#  'flaggedPosition!=0,"Operator is not registered in the pool"',
#  'isOperatorRegistered(operator),"Operator is not registered in the pool"',
#  'index<currentNode.sumWeight(),"Index exceeds weight"',
#  'emptyLeavesInStack,"Pool is full"',
#  '_array.length>0,"No value to peek, array is empty"',
#  '_array.length>0,"No value to pop, array is empty"',
#  'governance==msg.sender,"Not authorized"',
#  'registryKeeper==msg.sender,"Not authorized"',
#  'panicButton!=address(0),"Panic button disabled"',
#  'panicButton==msg.sender,"Not authorized"',
#  'isNewOperatorContract(_operatorContract),"Not a new operator contract"',
#  'isApprovedOperatorContract(_operatorContract),"Not an approved operator contract"',
#  'panicButtons[_operatorContract]!=address(0),"Disabled panic button cannot be updated"',
#  '_panicButton!=address(0),"Panic button must be non-zero address"',
#  'panicButtons[_operatorContract]!=address(0),"Panic button already disabled"',
#  'isApprovedOperatorContract(operatorContract),"Operator contract unapproved"',
#  'authorizerOf(_operator)==msg.sender,"Not operator authorizer"',
#  'getAuthoritySource(_operatorContract)==_operatorContract,"Delegated authority used"',
#  'AuthorityDelegator(delegatedAuthoritySource).__isRecognized(msg.sender),"Unrecognized claimant"',
#  'IERC20(token)==keepToken,"Not a KEEP token"',
#  'msg.sender==token,"KEEP token is not the sender"',
#  'extraData.length==64,"Unexpected data length"',
#  'extraData.length==60,"Corrupted delegation data"',
#  'isGrantee(msg.sender,grantId),"Not authorized"',
#  'getAmountRevoked(grantId)==0,"Grant revoked"',
#  'availableAmount(previousOperator)>=amount,"Insufficient balance"',
#  '!hasDeposit(newOperator),"Redelegating to previously used operator is not allowed"',
#  '!success,"Can not be called for managed grant"',
#  'msg.sender==grantee||msg.sender==operator,"Only grantee or operator can withdraw"',
#  'msg.sender==grantee||msg.sender==operator,"Only grantee or operator can withdraw"',
#  'isGrantee(msg.sender,deposit.grantId),"Not authorized"',
#  'authorizedEscrows[grantManager][receivingEscrow],"Escrow not authorized"',
#  'getAmountRevoked(deposit.grantId)>0,"No revoked tokens to withdraw"',
#  'anotherEscrow!=address(0x0),"Escrow address can\'t be zero"',
#  'from==owner(),"Only owner can deposit"',
#  'getAmountGranted(grantId)>0,"Grant with this ID does not exist"',
#  '!hasDeposit(operator),"Stake for the operator already deposited in the escrow"',
#  'ManagedGrant(managedGrantContract).grantee()==grantee,"Not a grantee of the provided contract"',
#  'extraData.length==92,"Corrupted delegation data from escrow"',
#  'grantId!=0,"No grant for the operator"',
#  '_tokenAddress!=address(0x0),"Token address can\'t be zero."',
#  '_stakingContract!=address(0x0),"Staking contract address can\'t be zero"',
#  'ERC20Burnable(_token)==token,"Token contract must be the same one linked to this contract."',
#  '_amount<=token.balanceOf(_from),"Sender must have enough amount."',
#  '_grantee!=address(0),"Grantee address can\'t be zero."',
#  '_cliffDuration<=_duration,"Unlocking cliff duration must be less or equal total unlocking duration."',
#  '_stakingPolicy!=address(0),"Staking policy can\'t be zero."',
#  'amount>0,"Grant available to withdraw amount should be greater than zero."',
#  'grants[_id].grantManager==msg.sender,"Only grant manager can revoke."',
#  'grants[_id].revocable,"Grant must be revocable in the first place."',
#  'grants[_id].revokedAt==0,"Grant must not be already revoked."',
#  'grant.grantManager==msg.sender,"Only grant manager can withdraw revoked tokens."',
#  'revokedWithdrawn<revoked,"All revoked tokens withdrawn."',
#  'remainingPresentInGrant>0,"No revoked tokens withdrawable."',
#  'grants[_id].grantee==msg.sender,"Only grantee of the grant can stake it."',
#  'grants[_id].revokedAt==0,"Revoked grant can not be staked"',
#  'stakingContracts[grants[_id].grantManager][_stakingContract],"Provided staking contract is not authorized."',
#  '_extraData.length==60,"Stake delegation data must be provided."',
#  '_amount<=availableToStake(_id),"Must have available granted amount to stake."',
#  'msg.sender==_operator||msg.sender==grants[grantId].grantee,"Only operator or grantee can cancel the delegation."',
#  'msg.sender==_operator||msg.sender==grants[grantId].grantee,"Only operator or grantee can undelegate."',
#  'grants[grantId].revokedAt!=0,"Grant must be revoked"',
#  'msg.sender==grants[grantId].grantManager,"Only grant manager can force cancellation of revoked grant stake."',
#  'grants[grantId].revokedAt!=0,"Grant must be revoked"',
#  'msg.sender==grants[grantId].grantManager,"Only grant manager can force undelegation of revoked grant stake"',
#  'duration<=maximumLockDuration,"Lock duration too long"',
#  'locks.contains(operatorContract),"No matching lock present"',
#  'expired||disabled,"Lock still active and valid"',
#  '!escrow.hasDeposit(operator),"Stake for the operator already deposited in the escrow"',
#  'value>0,"Top-up value must be greater than zero"',
#  '!isUndelegating(operatorParams),"Stake undelegated"',
#  '!escrow.hasDeposit(operator),"Stake for the operator already deposited in the escrow"',
#  'value>0,"Top-up value must be greater than zero"',
#  'topUp.amount>0,"No top up to commit"',
#  'now>topUp.createdAt.add(initializationPeriod),"Stake is initializing"',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,"SafeMath: subtraction overflow"',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,"SafeMath: division by zero"',
#  'b!=0,"SafeMath: modulo by zero"',
#  'msg.sender==operator||msg.sender.isTokenOwnerForOperator(operator,tokenStaking)||msg.sender.isGranteeForOperator(operator,tokenGrant),"Only operator or the owner is allowed to withdraw bond"',
#  'msg.sender.isManagedGranteeForOperator(operator,managedGrant,tokenGrant),"Only grantee is allowed to withdraw bond"',
#  'beneficiary!=address(0),"Beneficiary not defined for the operator"',
#  'availableUnbondedValue(operator,msg.sender,authorizedSortitionPool)>=amount,"Insufficient unbonded value"',
#  'lockedBonds[bondID]==0,"Reference ID not unique for holder and operator"',
#  'lockedBonds[bondID]>0,"Bond not found"',
#  'lockedBonds[newBondID]==0,"Reference ID not unique for holder and operator"',
#  'lockedBonds[bondID]>0,"Bond not found"',
#  'amount>0,"Requested amount should be greater than zero"',
#  'lockedBonds[bondID]>=amount,"Requested amount is greater than the bond"',
#  'success,"Transfer failed"',
#  'authorizerOf(_operator)==msg.sender,"Not authorized"',
#  'authorizerOf(_operator)==msg.sender,"Not authorized"',
#  'unbondedValue[operator]>=amount,"Insufficient unbonded value"',
#  'success,"Transfer failed"',
#  'ok,string(returnData)',
#  'msg.sender==owner',
#  'newOwner!=address(0)',
#  'super.transfer(_receiver,_amount)',
#  'split*2>=split',
#  'balances[msg.sender]>=_value+lockAmounts[msg.sender]',
#  'balances[_from]>=_value+lockAmounts[_from]',
#  '!isContract(msg.sender)',
#  'balanceOf[msg.sender]>=wad',
#  'balanceOf[src]>=wad',
#  'allowance[src][msg.sender]>=wad',
#  'msg.sender==owner',
#  '_newOwner!=address(0)',
#  'authorized[msg.sender],"AccessControlledBase#requiresAuthorization: Sender not authorized"',
#  'block.timestamp<GRACE_PERIOD_EXPIRATION,"StaticAccessControlled#grantAccess: Cannot grant access after grace period"',
#  'withdrawableBalance!=0,"Vault#withdrawExcessToken: Withdrawable token amount must be non-zero"',
#  '_guardCounter==localCounter,"Reentrancy check failure"',
#  'precomputePrecision<=MAX_PRECOMPUTE_PRECISION,"Exponent#exp: Precompute precision over maximum"',
#  'newOwner!=address(0),"TransferInternal#grantLoanOwnership: New owner did not consent to owning loan"',
#  'newOwner!=address(0),"TransferInternal#grantPositionOwnership: New owner did not consent to owning position"',
#  'osition.requiredDeposit==0',
#  'position.startTimestamp!=0,"MarginCommon#getPositionFromStorage: The position does not exist"',
#  'PayoutRecipient(transaction.payoutRecipient).receiveClosePositionPayout(transaction.positionId,transaction.closeAmount,msg.sender,transaction.positionOwner,transaction.heldToken,payout,transaction.availableHeldToken,transaction.payoutInHeldToken),"ClosePositionShared#sendTokensToPayoutRecipient: Payout recipient does not consent"',
#  'payoutRecipient!=address(0),"ClosePositionShared#createCloseTx: Payout recipient cannot be 0"',
#  'requestedAmount>0,"ClosePositionShared#createCloseTx: Requested close amount cannot be 0"',
#  'newCloseAmount<=closeAmount,"ClosePositionShared#closePositionRecurse: newCloseAmount is greater than closeAmount"',
#  'newCloseAmount>0,"ClosePositionShared#closePositionRecurse: newCloseAmount is zero"',
#  'newCloseAmount<=closeAmount,"ClosePositionShared#closeLoanRecurse: newCloseAmount is greater than closeAmount"',
#  'newCloseAmount>0,"ClosePositionShared#closeLoanRecurse: newCloseAmount is zero"',
#  'transaction.payoutInHeldToken,"ClosePositionImpl#returnOwedTokensToLender: Cannot payout in owedToken"',
#  'buybackCostInHeldToken<=transaction.availableHeldToken,"ClosePositionImpl#buyBackOwedToken: Not enough available heldToken"',
#  'receivedOwedToken>=transaction.owedTokenOwed,"ClosePositionImpl#buyBackOwedToken: Did not receive enough owedToken"',
#  'depositAmount>0,"DepositCollateralImpl#depositCollateralImpl: Deposit amount cannot be 0"',
#  '.requiredDeposit=',
#  '.requiredDeposit=position.requiredDeposit.sub(depositAmount',
#  'signatureWithType.length==66,"SignatureValidator#validateSignature: invalid signature length"',
#  'sigType>uint8(SIGTYPE_INVALID),"SignatureValidator#validateSignature: invalid signature type"',
#  'sigType<uint8(SIGTYPE_UNSUPPORTED),"SignatureValidator#validateSignature: unsupported signature type"',
#  'transaction.principal>0,"BorrowShared#validateTxPreSell: Positions with 0 principal are not allowed"',
#  'msg.sender==transaction.loanOffering.taker,"BorrowShared#validateTxPreSell: Invalid loan offering taker"',
#  'transaction.owner==transaction.loanOffering.positionOwner,"BorrowShared#validateTxPreSell: Invalid position owner"',
#  'transaction.loanOffering.payer==TypedSignature.recover(transaction.loanOffering.loanHash,transaction.loanOffering.signature),"BorrowShared#validateTxPreSell: Invalid loan offering signature"',
#  'transaction.lenderAmount.add(unavailable)<=transaction.loanOffering.rates.maxAmount,"BorrowShared#validateTxPreSell: Loan offering does not have enough available"',
#  'transaction.lenderAmount>=transaction.loanOffering.rates.minAmount,"BorrowShared#validateTxPreSell: Lender amount is below loan offering minimum amount"',
#  'transaction.loanOffering.owedToken!=transaction.loanOffering.heldToken,"BorrowShared#validateTxPreSell: owedToken cannot be equal to heldToken"',
#  'transaction.owner!=address(0),"BorrowShared#validateTxPreSell: Position owner cannot be 0"',
#  'transaction.loanOffering.owner!=address(0),"BorrowShared#validateTxPreSell: Loan owner cannot be 0"',
#  'transaction.loanOffering.expirationTimestamp>block.timestamp,"BorrowShared#validateTxPreSell: Loan offering is expired"',
#  'transaction.loanOffering.maxDuration>0,"BorrowShared#validateTxPreSell: Loan offering has 0 maximum duration"',
#  'transaction.loanOffering.rates.interestPeriod<=transaction.loanOffering.maxDuration,"BorrowShared#validateTxPreSell: Loan offering interestPeriod > maxDuration"',
#  'transaction.collateralAmount>=loanOfferingMinimumHeldToken,"BorrowShared#validateTxPostSell: Loan offering minimum held token not met"',
#  'principalToAdd>0,"IncreasePositionImpl#increaseWithoutCounterpartyImpl: Cannot add 0 principal"',
#  'block.timestamp<uint256(position.startTimestamp).add(position.maxDuration),"IncreasePositionImpl#increaseWithoutCounterpartyImpl: Cannot increase after maxDuration"',
#  'transaction.heldTokenFromSell<=collateralToAdd,"IncreasePositionImpl#doBorrowAndSell: DEX order gives too much heldToken"',
#  'transaction.lenderAmount<=totalOwedToken,"IncreasePositionImpl#getOwedTokenDeposit: Lender amount is more than required"',
#  'position.callTimeLimit<=transaction.loanOffering.callTimeLimit,"IncreasePositionImpl#validateIncrease: Loan callTimeLimit is less than the position"',
#  'positionEndTimestamp<=offeringEndTimestamp,"IncreasePositionImpl#validateIncrease: Loan end timestamp is less than the position"',
#  'block.timestamp<positionEndTimestamp,"IncreasePositionImpl#validateIncrease: Position has passed its maximum duration"',
#  'position.callTimestamp==0,"LoanImpl#marginCallImpl: The position has already been margin-called"',
#  '.requiredDeposit=requiredDeposi',
#  'position.callTimestamp>0,"LoanImpl#cancelMarginCallImpl: Position has not been margin-called"',
#  'sitions[positionId].requiredDeposit=',
#  'msg.sender==loanOffering.payer,"LoanImpl#cancelLoanOfferingImpl: Only loan offering payer can cancel"',
#  'loanOffering.expirationTimestamp>block.timestamp,"LoanImpl#cancelLoanOfferingImpl: Loan offering has already expired"',
#  'operationState==OPERATION_STATE_OPERATIONAL,"MarginAdmin#onlyWhileOperational: Can only call while operational"',
#  'operationState==OPERATION_STATE_OPERATIONAL||operationState==OPERATION_STATE_CLOSE_AND_CANCEL_LOAN_ONLY,"MarginAdmin#cancelLoanOfferingStateControl: Invalid operation state"',
#  'operationState==OPERATION_STATE_OPERATIONAL||operationState==OPERATION_STATE_CLOSE_AND_CANCEL_LOAN_ONLY||operationState==OPERATION_STATE_CLOSE_ONLY,"MarginAdmin#closePositionStateControl: Invalid operation state"',
#  'newState<OPERATION_STATE_INVALID,"MarginAdmin#setOperationState: newState is not a valid operation state"',
#  '!MarginCommon.positionHasExisted(state,transaction.positionId),"OpenPositionImpl#openPositionImpl: positionId already exists"',
#  '!MarginCommon.positionHasExisted(state,openTx.positionId),"openWithoutCounterpartyImpl#validate: positionId already exists"',
#  'openTx.principal>0,"openWithoutCounterpartyImpl#validate: principal cannot be 0"',
#  'openTx.owedToken!=address(0),"openWithoutCounterpartyImpl#validate: owedToken cannot be 0"',
#  'openTx.owedToken!=openTx.heldToken,"openWithoutCounterpartyImpl#validate: owedToken cannot be equal to heldToken"',
#  'openTx.positionOwner!=address(0),"openWithoutCounterpartyImpl#validate: positionOwner cannot be 0"',
#  'openTx.loanOwner!=address(0),"openWithoutCounterpartyImpl#validate: loanOwner cannot be 0"',
#  'openTx.maxDuration>0,"openWithoutCounterpartyImpl#validate: maxDuration cannot be 0"',
#  'openTx.interestPeriod<=openTx.maxDuration,"openWithoutCounterpartyImpl#validate: interestPeriod must be <= maxDuration"',
#  'timestamp>=position.startTimestamp,"PositionGetters#getPositionOwedAmountAtTime: Requested time before position started"',
#  'timestamp>=position.startTimestamp,"PositionGetters#getLenderAmountForIncreasePositionAtTime: timestamp < position start"',
#  'MarginCommon.containsPositionImpl(state,positionId),"TransferImpl#transferLoanImpl: Position does not exist"',
#  'msg.sender==originalLender,"TransferImpl#transferLoanImpl: Only lender can transfer ownership"',
#  'newLender!=originalLender,"TransferImpl#transferLoanImpl: Cannot transfer ownership to self"',
#  'finalLender!=originalLender,"TransferImpl#transferLoanImpl: Cannot ultimately transfer ownership to self"',
#  'MarginCommon.containsPositionImpl(state,positionId),"TransferImpl#transferPositionImpl: Position does not exist"',
#  'msg.sender==originalOwner,"TransferImpl#transferPositionImpl: Only position owner can transfer ownership"',
#  'newOwner!=originalOwner,"TransferImpl#transferPositionImpl: Cannot transfer ownership to self"',
#  'finalOwner!=originalOwner,"TransferImpl#transferPositionImpl: Cannot ultimately transfer ownership to self"',
#  'msg.sender==DYDX_MARGIN,"OnlyMargin#onlyMargin: Only Margin can call"',
#  'parameters[0]!=0,"BucketLender#constructor: BUCKET_TIME cannot be zero"',
#  'POSITION_ID==positionId,"BucketLender#onlyPosition: Incorrect position"',
#  'Margin(DYDX_MARGIN).containsPosition(POSITION_ID),"BucketLender#verifyLoanOffering: This contract should not open a new position"',
#  'loanOffering.taker==address(0),"BucketLender#verifyLoanOffering: loanOffering.taker is non-zero"',
#  'loanOffering.feeRecipient==address(0),"BucketLender#verifyLoanOffering: loanOffering.feeRecipient is non-zero"',
#  'loanOffering.positionOwner==address(0),"BucketLender#verifyLoanOffering: loanOffering.positionOwner is non-zero"',
#  'loanOffering.lenderFeeToken==address(0),"BucketLender#verifyLoanOffering: loanOffering.lenderFeeToken is non-zero"',
#  'loanOffering.takerFeeToken==address(0),"BucketLender#verifyLoanOffering: loanOffering.takerFeeToken is non-zero"',
#  'loanOffering.rates.maxAmount==MathHelpers.maxUint256(),"BucketLender#verifyLoanOffering: loanOffering.maxAmount is incorrect"',
#  'loanOffering.rates.minAmount==0,"BucketLender#verifyLoanOffering: loanOffering.minAmount is non-zero"',
#  'loanOffering.rates.minHeldToken==0,"BucketLender#verifyLoanOffering: loanOffering.minHeldToken is non-zero"',
#  'loanOffering.rates.lenderFee==0,"BucketLender#verifyLoanOffering: loanOffering.lenderFee is non-zero"',
#  'loanOffering.rates.takerFee==0,"BucketLender#verifyLoanOffering: loanOffering.takerFee is non-zero"',
#  'loanOffering.expirationTimestamp==MathHelpers.maxUint256(),"BucketLender#verifyLoanOffering: expirationTimestamp is incorrect"',
#  'loanOffering.salt==0,"BucketLender#verifyLoanOffering: loanOffering.salt is non-zero"',
#  'loanOffering.callTimeLimit==MathHelpers.maxUint32(),"BucketLender#verifyLoanOffering: loanOffering.callTimelimit is incorrect"',
#  'loanOffering.maxDuration==MathHelpers.maxUint32(),"BucketLender#verifyLoanOffering: loanOffering.maxDuration is incorrect"',
#  'position.owedToken==OWED_TOKEN,"BucketLender#receiveLoanOwnership: Position owedToken mismatch"',
#  'position.heldToken==HELD_TOKEN,"BucketLender#receiveLoanOwnership: Position heldToken mismatch"',
#  'position.maxDuration==MAX_DURATION,"BucketLender#receiveLoanOwnership: Position maxDuration mismatch"',
#  'position.callTimeLimit==CALL_TIMELIMIT,"BucketLender#receiveLoanOwnership: Position callTimeLimit mismatch"',
#  'position.interestRate==INTEREST_RATE,"BucketLender#receiveLoanOwnership: Position interestRate mismatch"',
#  'position.interestPeriod==INTEREST_PERIOD,"BucketLender#receiveLoanOwnership: Position interestPeriod mismatch"',
#  'Margin(DYDX_MARGIN).getPositionBalance(POSITION_ID)>=minHeldToken,"BucketLender#receiveLoanOwnership: Not enough heldToken as collateral"',
#  'payer==address(this),"BucketLender#increaseLoanOnBehalfOf: Other lenders cannot lend for this position"',
#  '!margin.isPositionCalled(POSITION_ID),"BucketLender#increaseLoanOnBehalfOf: No lending while the position is margin-called"',
#  'TRUSTED_MARGIN_CALLERS[caller],"BucketLender#marginCallOnBehalfOf: Margin-caller must be trusted"',
#  'depositAmount==0,"BucketLender#marginCallOnBehalfOf: Deposit amount must be zero"',
#  'TRUSTED_MARGIN_CALLERS[canceler],"BucketLender#cancelMarginCallOnBehalfOf: Margin-call-canceler must be trusted"',
#  'beneficiary!=address(0),"BucketLender#deposit: Beneficiary cannot be the zero address"',
#  'amount!=0,"BucketLender#deposit: Cannot deposit zero tokens"',
#  '!margin.isPositionClosed(positionId),"BucketLender#deposit: Cannot deposit after the position is closed"',
#  '!margin.isPositionCalled(positionId),"BucketLender#deposit: Cannot deposit while the position is margin-called"',
#  'weightToAdd!=0,"BucketLender#deposit: Cannot deposit for zero weight"',
#  'buckets.length==maxWeights.length,"BucketLender#withdraw: The lengths of the input arrays must match"',
#  'TRUSTED_WITHDRAWERS[msg.sender],"BucketLender#withdraw: Only trusted withdrawers can withdraw on behalf of others"',
#  '!wasForceClosed,"BucketLender#withdrawExcessToken: heldToken cannot be withdrawn if force-closed"',
#  'recipient==address(this),"BucketLender#forceRecoverCollateralOnBehalfOf: Recipient must be this contract"',
#  'lentAmount<=availableTotal,"BucketLender#accountForIncrease: No lending not-accounted-for funds"',
#  'owedTokenToWithdraw<=availableForBucket[bucket],"BucketLender#withdrawOwedToken: There must be enough available owedToken"',
#  'msg.sender==WETH,"BucketLenderProxy#fallback: Cannot recieve ETH directly unless unwrapping WETH"',
#  'weth==BucketLender(bucketLender).OWED_TOKEN(),"BucketLenderProxy#depositEth: BucketLender does not take WETH"',
#  'owedToken==BucketLender(withdrawFrom).OWED_TOKEN(),"BucketLenderTokenProxy#rollover: Token mismatch"',
#  'Address.isContract(newImplementation),"ERC1967: new implementation is not a contract"',
#  'oldImplementation==_getImplementation(),"ERC1967Upgrade: upgrade breaks further upgrades"',
#  'newAdmin!=address(0),"ERC1967: new admin is the zero address"',
#  'Address.isContract(newBeacon),"ERC1967: new beacon is not a contract"',
#  'Address.isContract(IBeacon(newBeacon).implementation()),"ERC1967: beacon implementation is not a contract"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  'owner()==_msgSender(),"Ownable: caller is not the owner"',
#  'newOwner!=address(0),"Ownable: new owner is the zero address"',
#  'success',
#  'success',
#  'msg.sender!=_getAdmin(),"TransparentUpgradeableProxy: admin cannot fallback to proxy target"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  'account!=address(0),"ERC20: mint to the zero address"',
#  'account!=address(0),"ERC20: burn from the zero address"',
#  'owner!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'msg.sender==pool_address,"must be pool"',
#  'msg.sender==pool_address,"must be pool"',
#  'msg.sender==pool_address,"must be pool"',
#  'c/a==b',
#  'b>0',
#  'b<=a',
#  'c>=a',
#  'b!=0',
#  'currentAllowance>=amount,"ERC20: transfer amount exceeds allowance"',
#  'currentAllowance>=subtractedValue,"ERC20: decreased allowance below zero"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  'senderBalance>=amount,"ERC20: transfer amount exceeds balance"',
#  'account!=address(0),"ERC20: mint to the zero address"',
#  'account!=address(0),"ERC20: burn from the zero address"',
#  'accountBalance>=amount,"ERC20: burn amount exceeds balance"',
#  'owner!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'balances[msg.sender]>=_value',
#  'msg.sender==owner',
#  'newOwner!=address(0)',
#  '_owner!=address(0)',
#  'PrintSeries[_seriesID],"Not a valid series"',
#  'PreMintData[_seriesID].amount_of_tokens_left>=1,"Series is SOLD OUT!"',
#  'msg.value>=PreMintData[_seriesID].price,"Invalid amount sent to purchase this NFT"',
#  'address(this).balance>=fee,"Not enough balance to send fee"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'isContract(target),"Address: static call to non-contract"',
#  'isContract(target),"Address: delegate call to non-contract"',
#  '_owner==_msgSender(),"Ownable: caller is not the owner"',
#  'amount<Emmental',
#  '!(Gouda[sender]==true)',
#  'currentAllowance>=subtractedValue,"ERC20: decreased allowance below zero"',
#  'account!=address(0),"ERC20: burn from the zero address"',
#  'currentAllowance>=amount,"ERC20: transfer amount exceeds allowance"',
#  'owner!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'account!=address(0),"ERC20: mint to the zero address"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  'senderBalance>=amount,"ERC20: transfer amount exceeds balance"',
#  'initializing||isConstructor()||!initialized,"Contract instance has already been initialized"',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,errorMessage',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,errorMessage',
#  'b!=0,errorMessage',
#  'OpenZeppelinUpgradesAddress.isContract(newImplementation),"Cannot set a proxy implementation to a non-contract address"',
#  'success',
#  'newAdmin!=address(0),"Cannot change the admin of a proxy to the zero address"',
#  'success',
#  'msg.sender!=_admin(),"Cannot call fallback function from the proxy admin"',
#  '_implementation()==address(0)',
#  'success',
#  '_implementation()==address(0)',
#  'isOwner(),"Ownable: caller is not the owner"',
#  'newOwner!=address(0),"Ownable: new owner is the zero address"',
#  '_msgSender()==pendingOwner,"Claimable: caller is not the pending owner"',
#  'newOwner!=owner()&&newOwner!=pendingOwner,"Claimable: invalid new owner"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  'account!=address(0),"ERC20: mint to the zero address"',
#  'account!=address(0),"ERC20: burn from the zero address"',
#  'owner!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  '(value==0)||(token.allowance(address(this),spender)==0),"SafeERC20: approve from non-zero to non-zero allowance"',
#  'address(token).isContract(),"SafeERC20: call to non-contract"',
#  'success,"SafeERC20: low-level call failed"',
#  'abi.decode(returndata,(bool)),"SafeERC20: ERC20 operation did not succeed"',
#  '!recoverableTokensBlacklist[_token],"CanReclaimTokens: token is not recoverable"',
#  'holder!=address(0),"ERC20WithRate: address must not be 0x0"',
#  'holder==ecrecover(digest,v,r,s),"ERC20WithRate: invalid signature"',
#  'expiry==0||now<=expiry,"ERC20WithRate: permit has expired"',
#  'nonce==nonces[holder]++,"ERC20WithRate: invalid nonce"',
#  'recipient!=address(this),"TornomyERC20: can\'t transfer to token address"',
#  'recipient!=address(this),"TornomyERC20: can\'t transfer to token address"',
#  'msg.sender==mintAuthority||msg.sender==owner(),"Gateway: caller is not the owner or mint authority"',
#  '_nextMintAuthority!=address(0),"Gateway: mintAuthority cannot be set to address zero"',
#  '_nextFeeRecipient!=address(0x0),"Gateway: fee recipient cannot be 0x0"',
#  'status[signedMessageHash]==false,"Gateway: nonce hash already spent"',
#  'token.transferFrom(_msgSender(),address(this),_amount),"token transfer failed"',
#  '_to.length!=0,"Gateway: to address is empty"',
#  'amountAfterFee>minimumBurnAmount,"Gateway: amount is less than the minimum burn amount"',
#  'c>=a',
#  'b<=a',
#  'a==0||c/a==b',
#  'b>0',
#  'msg.sender==owner',
#  'state==_state',
#  'state!=_state',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,errorMessage',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,errorMessage',
#  'b!=0,errorMessage',
#  "numTokens<=balances[msg.sender],'Amount exceeds balance.'",
#  "numTokens<=balances[msg.sender],'Amount exceeds balance.'",
#  "addedValue<=balances[msg.sender].sub(allowed[msg.sender][spender]),'Amount exceeds balance.'",
#  "subtractedValue<=allowed[msg.sender][spender],'Amount exceeds balance.'",
#  "numTokens<=balances[owner],'Amount exceeds balance.'",
#  "numTokens<=allowed[owner][msg.sender],'Amount exceeds allowance.'",
#  'amount<=balances[msg.sender]',
#  'amount<20,"Amount to low to process"',
#  'amount<=stakedbalances[msg.sender]',
#  'amount<=totalstaked',
#  'amount<20,"Amount to low to process"',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  'account!=address(0),"ERC20: mint to the zero address"',
#  'account!=address(0),"ERC20: burn from the zero address"',
#  'owner!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'value>=1000,"ImpliedVolRate limit is too small"',
#  'recipient!=address(0)',
#  'strikeAmount>0,"Amount is too small"',
#  'settlementFee<total,"Premium is too small"',
#  'period>=1days,"Period is too short"',
#  'period<=4weeks,"Period is too long"',
#  'msg.value==total,"Wrong value"',
#  'option.expiration>=now,"Option has expired"',
#  'option.holder==msg.sender,"Wrong msg.sender"',
#  'option.state==State.Active,"Wrong state"',
#  'option.expiration<now,"Option has not expired yet"',
#  'option.state==State.Active,"Option is not active"',
#  'now<contractCreationTimestamp+90days',
#  'value<=60days,"Lockup period is too large"',
#  'option.strike<=currentPrice,"Current price is too low"',
#  'now<contractCreationTimestamp+90days',
#  'value<=95,"Spread limit is too small"',
#  'value<=60days,"Lockup period is too large"',
#  'token.approve(address(pool),uint256(-1)),"token approve failed"',
#  'option.strike>=currentPrice,"Current price is too high"',
#  'ownerCount<=MAX_OWNER_COUNT&&_required<=ownerCount&&_required>=1',
#  '=_require',
#  'destination!=address(this),"Not allow sending to yourself"',
#  'address(this).balance>=value&&value>0,"balance or spend value invalid"',
#  '_validSignature(address(0x0),destination,value,vs,rs,ss),"invalid signatures"',
#  'destination!=address(this),"Not allow sending to yourself"',
#  'value>0,"Erc20 spend value invalid"',
#  '_validSignature(erc20contract,destination,value,vs,rs,ss),"invalid signatures"',
#  'destination!=address(this),"Not allow sending to yourself"',
#  '_validSignature(address(0x9),destination,value,vs,rs,ss),"invalid signatures"',
#  'vs.length==rs.length',
#  'rs.length==ss.length',
#  'vs.length<=owners.length',
#  'vs.length>=required',
#  '_distinctOwners(addrs)',
#  '_to!=address(0)',
#  '_value<=balances[msg.sender]',
#  '_to!=address(0)',
#  '_value<=balances[_from]',
#  '_value<=allowed[_from][msg.sender]',
#  'msg.sender==owner',
#  'newOwner!=address(0)',
#  '!mintingFinished',
#  'msg.sender==owner||(mintingFinished&&!locked[msg.sender])',
#  '!mintingFinished',
#  'currentAllowance>=amount,"ERC20: transfer amount exceeds allowance"',
#  'currentAllowance>=subtractedValue,"ERC20: decreased allowance below zero"',
#  'sender!=address(0),"ERC20: transfer from the zero address"',
#  'recipient!=address(0),"ERC20: transfer to the zero address"',
#  'senderBalance>=amount,"ERC20: transfer amount exceeds balance"',
#  'account!=address(0),"ERC20: mint to the zero address"',
#  'account!=address(0),"ERC20: burn from the zero address"',
#  'accountBalance>=amount,"ERC20: burn amount exceeds balance"',
#  'owner!=address(0),"ERC20: approve from the zero address"',
#  'spender!=address(0),"ERC20: approve to the zero address"',
#  'c>=a,"SafeMath: addition overflow"',
#  'b<=a,errorMessage',
#  'c/a==b,"SafeMath: multiplication overflow"',
#  'b>0,errorMessage',
#  'b!=0,errorMessage',
#  'address(this).balance>=amount,"Address: insufficient balance"',
#  'success,"Address: unable to send value, recipient may have reverted"',
#  'address(this).balance>=value,"Address: insufficient balance for call"',
#  'isContract(target),"Address: call to non-contract"',
#  'msg.sender==_owner,"!owner"',
#  'msg.sender==_owner,"!owner"',
#  'msg.sender==_owner,"!owner"',
#  ...]

# %%
import os

base_model = "codellama/CodeLlama-7b-hf"

# %%
from transformers import AutoTokenizer
MAX_SEQ_LEN = 16384/4

tokenizer = AutoTokenizer.from_pretrained(base_model,
                                         truncation=False,
                                         model_max_length=MAX_SEQ_LEN,
                                         padding_side="left",
                                         use_fast=True,
                                         )

# %% [markdown]
# ## Tokenization

# %%
tokenizer.add_eos_token = True
tokenizer.pad_token_id = 0

def tokenize(text, tokenizer, max_seq_len=MAX_SEQ_LEN):
    result = tokenizer(
        text,
        truncation=False,
        max_length=max_seq_len,
        padding=False,
        return_tensors=None,
    )
    if len(result['input_ids']) > max_seq_len:
        return None
        
    return result
    
def generate_and_tokenize_prompt(sample):
    input_text = sample['input']
    target_text = sample['predicate']
    
    tokenized_input_text = tokenize(input_text, tokenizer, max_seq_len=MAX_SEQ_LEN)
    tokenized_target_text = tokenize(target_text, tokenizer, max_seq_len=MAX_SEQ_LEN)

    if tokenized_input_text is None or tokenized_target_text is None:
        return  {"input_ids": None, "attention_mask": None, "labels": None}
    else:
        return {'input_ids': tokenized_input_text['input_ids'][:-1] + tokenized_target_text['input_ids'][1:], 
                  'attention_mask': [1] * len(tokenized_input_text['input_ids'][:-1] + tokenized_target_text['input_ids'][1:]),
                  'labels': [-100] * len(tokenized_input_text['input_ids'][:-1]) + tokenized_target_text['input_ids'][1:],
                }

# %%
tokenized = dataset['train'].map(generate_and_tokenize_prompt, 
                                remove_columns=['comment', 'input', 'label', 'predicate'],
                                num_proc=10,
                      )
# Out:
# Map (num_proc=10): 100%|██████████| 5282156/5282156 [1:39:11<00:00, 887.46 examples/s]

# %%
train_tokenized = tokenized.filter(lambda sample: sample["input_ids"] is not None)
# Out:
# Filter: 100%|██████████| 5282156/5282156 [1:15:15<00:00, 1169.89 examples/s]

# %%
train_tokenized.push_to_hub("GGmorello/FLAMES_only_predicates", data_dir='data/tokenized_with_idx')
# Out:
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.36ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.40ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.43ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.48ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.14ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.33ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.39ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.23ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.32ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.03ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:05<00:00,  5.38ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.50ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.40ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.09ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.23ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.23ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.09ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.39ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.18ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.23ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.20ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.12ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.04ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.30ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.24ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:05<00:00,  5.59ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.93ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.76ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.00ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.97ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:05<00:00,  5.44ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.13ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.93ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:05<00:00,  4.76ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.90ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.84ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.35ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.23ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.38ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.16ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.18ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.22ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.81ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.33ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.09ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.09ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.14ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.05ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.27ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.09ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.26ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.33ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.27ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.17ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.97ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.09ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.26ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.04ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:05<00:00,  5.30ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.17ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.29ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.23ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.20ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.16ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.21ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.40ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.28ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.31ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.49ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.34ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.21ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.19ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.78ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.44ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.53ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.31ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.30ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.36ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.02ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.49ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.57ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.34ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.00ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.18ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.12ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.48ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.16ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.41ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.08ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.02ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.53ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.33ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.37ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.38ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:03<00:00,  7.37ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.27ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.71ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.38ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.54ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.24ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.32ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.38ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.16ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.99ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.29ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.29ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.31ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.19ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.11ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.78ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.38ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.37ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.24ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.24ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.11ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.19ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.33ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  5.82ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.05ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.09ba/s]
# Creating parquet from Arrow format: 100%|██████████| 28/28 [00:04<00:00,  6.22ba/s]
# Uploading the dataset shards: 100%|██████████| 121/121 [12:53<00:00,  6.39s/it]
# CommitInfo(commit_url='https://huggingface.co/datasets/GGmorello/FLAMES_only_predicates/commit/957217d07024c1af79c69d163c6e13366ebd7d3b', commit_message='Upload dataset (part 00002-of-00003)', commit_description='', oid='957217d07024c1af79c69d163c6e13366ebd7d3b', pr_url=None, pr_revision=None, pr_num=None)
