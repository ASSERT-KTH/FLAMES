# %%
import validation_library as veri   
import os  
import importlib

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

importlib.reload(veri)

counter_greater_than_200 = 0

contract_lines_4X = []
contract_lines_8X = []

contracts_4X = veri.get_files("/home/matteo/FLAMES/validation-results/sb-heists/smartbugs-curated/0.4.x/contracts/dataset")

for contract_path, contract_name in contracts_4X:
    contract, line = veri.find_occurrences(contract_path, "// <yes> <report>")
    if contract.count('\n') > 200:
        counter_greater_than_200 += 1 
    else:
        clean_contract = veri.replace_lines_with_string(contract, line, '')
        contract_lines_4X.append((contract_name, clean_contract, line))

veri.print_json_report("reports/aggregated/contract_no_comment.json", contract_lines_4X)
veri.print_txt_report("reports/aggregated/contract_no_comment.txt", contract_lines_4X)

# %%
importlib.reload(veri)

contracts_with_results = veri.read_json_report("reports/aggregated/CL/contracts_PVP.json") 
contract_lines = veri.read_json_report("reports/aggregated/contract_no_comment.json")

# %%
importlib.reload(veri)
headers = [
    'Solidity_file_name',
    'vulnerability_type',
    'vulnerable_line_number',
    'vulnerability_function_entry_line',
    'vulnerability_function_end_line',
    'VL',
    'pre_post_',
    'pre',
    'post',
    'pre_VL_post',
    'pre_VL',
    'VL_post'
]

veri.create_csv_if_not_exists('/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv', headers)

for contract in contract_lines: 
        contract_name = contract[0]
        contract_code = contract[1]
        lines = contract[2]
        
        for contract_patch_VL in contracts_with_results[contract[0]]: 
                contract_patch = contract_patch_VL[0]
                VL_line,VL_require = contract_patch_VL[1]["VL"]
                pre_line,pre_require = contract_patch_VL[1]["pre"]
                post_line,post_require = contract_patch_VL[1]["post"]
                contract_patch = veri.replace_lines_with_string(contract_patch, [VL_line], VL_require)
                patch_VL = (contract_patch, VL_line, VL_require)    
                # VL  
                no_test, result_VL = veri.evaluate_contracts(contract, patch_VL)
                if no_test:
                        break

                # Pre
                
                contract_patch_pre = veri.insert_empty_line(contract_code, pre_line)
                contract_patch_pre = veri.replace_lines_with_string(contract_patch_pre, [pre_line], pre_require) 
                patch_pre = (contract_patch_pre, pre_line, pre_require)
                no_test, result_pre = veri.evaluate_contracts(contract, patch_pre)

                # Post
                contract_patch_post = veri.insert_empty_line(contract_code, post_line)
                contract_patch_post = veri.replace_lines_with_string(contract_patch_post, [post_line], post_require)
                patch_post = (contract_patch_post, post_line, post_require)
                no_test, result_post = veri.evaluate_contracts(contract, patch_post)

                # Pre + Post
                contract_patch_pre_post = veri.insert_empty_line(contract_code, post_line)
                contract_patch_pre_post = veri.replace_lines_with_string(contract_patch_pre_post, [post_line], post_require)
                contract_patch_pre_post = veri.insert_empty_line(contract_patch_pre_post, pre_line)
                contract_patch_pre_post = veri.replace_lines_with_string(contract_patch_pre_post, [pre_line], pre_require) 
                
                patch_lines = f"{pre_line},{post_line}"
                PP_require = f"{pre_require},{post_require}"
                patch_pre_post = (contract_patch_pre_post, patch_lines, PP_require)
                no_test, result_pre_post = veri.evaluate_contracts(contract, patch_pre_post)

                # Pre + VL + Post (PVP)
                contract_patch_PVP = veri.insert_empty_line(contract_patch, post_line)
                contract_patch_PVP = veri.replace_lines_with_string(contract_patch_PVP, [post_line], post_require)
                
                contract_patch_PVP = veri.insert_empty_line(contract_patch_PVP, pre_line)
                contract_patch_PVP= veri.replace_lines_with_string(contract_patch_PVP, [pre_line], pre_require) 

                patch_lines = f"{pre_line},{VL_line},{post_line}"
                PVP_require = f"{pre_require},{VL_require},{post_require}"
                patch_PVP = (contract_patch_PVP, patch_lines, PVP_require)
                no_test, result_PVP = veri.evaluate_contracts(contract, patch_PVP)

                # Pre + VL (PV)
                contract_patch_PV = veri.insert_empty_line(contract_patch, pre_line)
                contract_patch_PV= veri.replace_lines_with_string(contract_patch_PV, [pre_line], pre_require) 

                patch_lines = f"{pre_line},{VL_line}"
                PV_require = f"{pre_require},{VL_require}"
                patch_PV = (contract_patch_PV, patch_lines, PV_require)
                no_test, result_PV = veri.evaluate_contracts(contract, patch_PV)

                # VL + Post (VP) 
                contract_patch_VP = veri.insert_empty_line(contract_patch, post_line)
                contract_patch_VP = veri.replace_lines_with_string(contract_patch_VP, [post_line], post_require)

                patch_lines = f"{VL_line},{post_line}"
                VP_require = f"{VL_require},{post_require}"
                patch_VP = (contract_patch_VP, patch_lines, VP_require)
                no_test, result_VP = veri.evaluate_contracts(contract, patch_VP)

            
                type_V = veri.get_directory_name(contract_name,"/home/matteo/FLAMES/validation-results/sb-heists/smartbugs-curated")
              

                row = {
                'Solidity_file_name': contract_name,
                'vulnerability_type': type_V,
                'vulnerable_line_number': VL_line,
                'vulnerability_function_entry_line': pre_line - 1,
                'vulnerability_function_end_line': post_line,
                'VL': result_VL,
                'pre_post_': result_pre_post,
                'pre': result_pre,
                'post': result_post,
                'pre_VL_post': result_PVP,
                'pre_VL': result_PV,
                'VL_post': result_VP
                }

                veri.append_row('/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv', headers, row)

                strategy_patch_map = {
                        'VL': contract_patch, 
                        'pre': contract_patch_pre,
                        'post': contract_patch_post,
                        'pre_post': contract_patch_pre_post,
                        'pre_VL_post': contract_patch_PVP,
                        'pre_VL': contract_patch_PV,
                        'VL_post': contract_patch_VP
                }

                veri.save_patches_by_strategy(
                        output_dir='/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/CL/patches_CL/',
                        contract_name=contract_name,
                        strategy_patch_map=strategy_patch_map
                )
# Out:
# CSV file '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' created successfully in Excel-friendly format.
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender == tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors2() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors3() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors4() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors5() public {
# require();
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require();
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,20] Evaluation Results:
# Inserted Require: require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors2() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors3() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors4() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors5() public {
# require();,require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require();
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,15,20] Evaluation Results:
# Inserted Require: require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors2() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors3() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors4() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors5() public {
# require();,require(msg.sender == tx.origin);,require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require();
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,15] Evaluation Results:
# Inserted Require: require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors2() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors3() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors4() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors5() public {
# require();,require(msg.sender == tx.origin);
#
# === Evaluating patches for contract: dos_address.sol ===
#
# [Patch on line 15,20] Evaluation Results:
# Inserted Require: require(msg.sender == tx.origin);,require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require(msg.sender == tx.origin);
#         if(creditorAddresses.length>1500) {
#             creditorAddresses = new address[](0);
#             win = true;
#         }
#     }
#
#     function emptyCreditors1() public {
# require();
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(numElements<382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(value>0);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(numElements==numbers);
#     }
#
#     function getElement(uint index) public view returns(uint) {
#         require(index<numElements);
#         return array[index];
#     }
#
#     function getLastElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElement() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements/2];
#     }
#
#     function getLastElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,24] Evaluation Results:
# Inserted Require: require(value>0);,require(numElements==numbers);
#     }
#
#     function getElement(uint index) public view returns(uint) {
#         require(index<numElements);
#         return array[index];
#     }
#
#     function getLastElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElement() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements/2];
#     }
#
#     function getLastElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,17,24] Evaluation Results:
# Inserted Require: require(value>0);,require(numElements<382);,require(numElements==numbers);
#     }
#
#     function getElement(uint index) public view returns(uint) {
#         require(index<numElements);
#         return array[index];
#     }
#
#     function getLastElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElement() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements/2];
#     }
#
#     function getLastElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 15,17] Evaluation Results:
# Inserted Require: require(value>0);,require(numElements<382);
#
# === Evaluating patches for contract: dos_number.sol ===
#
# [Patch on line 17,24] Evaluation Results:
# Inserted Require: require(numElements<382);,require(numElements==numbers);
#     }
#
#     function getElement(uint index) public view returns(uint) {
#         require(index<numElements);
#         return array[index];
#     }
#
#     function getLastElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElement() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElement() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements/2];
#     }
#
#     function getLastElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[numElements-1];
#     }
#
#     function getFirstElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return array[0];
#     }
#
#     function getMiddleElementWithIndex() public view returns(uint) {
#         require(numElements>0);
#         return);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.sender.balance >= 1000000000000000000);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(msg.sender.balance >= 1000000000000000000);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 26] Evaluation Results:
# Inserted Require: require(msg.sender.balance >= 1000000000000000000);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,26] Evaluation Results:
# Inserted Require: require(msg.sender.balance >= 1000000000000000000);,require(msg.sender.balance >= 1000000000000000000);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,16,26] Evaluation Results:
# Inserted Require: require(msg.sender.balance >= 1000000000000000000);,require(msg.sender.balance >= 1000000000000000000);,require(msg.sender.balance >= 1000000000000000000);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 15,16] Evaluation Results:
# Inserted Require: require(msg.sender.balance >= 1000000000000000000);,require(msg.sender.balance >= 1000000000000000000);
#
# === Evaluating patches for contract: dos_simple.sol ===
#
# [Patch on line 16,26] Evaluation Results:
# Inserted Require: require(msg.sender.balance >= 1000000000000000000);,require(msg.sender.balance >= 1000000000000000000);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 22] Evaluation Results:
# Inserted Require: require(msg.sender.send(currentBid));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.value > 0);
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 28] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,28] Evaluation Results:
# Inserted Require: require(msg.value > 0);,require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,22,28] Evaluation Results:
# Inserted Require: require(msg.value > 0);,require(msg.sender.send(currentBid));,require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 16,22] Evaluation Results:
# Inserted Require: require(msg.value > 0);,require(msg.sender.send(currentBid));
#
# === Evaluating patches for contract: auction.sol ===
#
# [Patch on line 22,28] Evaluation Results:
# Inserted Require: require(msg.sender.send(currentBid));,require(msg.sender.send(msg.value));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 22] Evaluation Results:
# Inserted Require: require(!unlocked);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21] Evaluation Results:
# Inserted Require: require(!unlocked);
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#     }
#
#     function unlock() public {
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress =);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 31] Evaluation Results:
# Inserted Require: require(msg.sender == owner);
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
# }
#
# pragma solidity ^0.4.15;
# contract NameRegistrar {
#
#     bool public unlocked = false;  // registrar locked, no name updates
#
#     struct NameRecord { // map hashes to addresses
#         bytes32 name;
#         address mappedAddress;
#     }
#
#     mapping(address => NameRecord) public registeredNameRecord; // records who registered names
#     mapping(bytes32 => address) public resolve; // resolves hashes to addresses
#
#     function register(bytes32 _name, address _mappedAddress) public {
# );
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,31] Evaluation Results:
# Inserted Require: require(!unlocked);
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#     }
#
#     function unlock() public {
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress =);,require(msg.sender == owner);
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
# }
#
# pragma solidity ^0.4.15;
# contract NameRegistrar {
#
#     bool public unlocked = false;  // registrar locked, no name updates
#
#     struct NameRecord { // map hashes to addresses
#         bytes32 name;
#         address mappedAddress;
#     }
#
#     mapping(address => NameRecord) public registeredNameRecord; // records who registered names
#     mapping(bytes32 => address) public resolve; // resolves hashes to addresses
#
#     function register(bytes32 _name, address _mappedAddress) public {
# );
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,22,31] Evaluation Results:
# Inserted Require: require(!unlocked);
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#     }
#
#     function unlock() public {
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress =);,require(!unlocked);,require(msg.sender == owner);
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
# }
#
# pragma solidity ^0.4.15;
# contract NameRegistrar {
#
#     bool public unlocked = false;  // registrar locked, no name updates
#
#     struct NameRecord { // map hashes to addresses
#         bytes32 name;
#         address mappedAddress;
#     }
#
#     mapping(address => NameRecord) public registeredNameRecord; // records who registered names
#     mapping(bytes32 => address) public resolve; // resolves hashes to addresses
#
#     function register(bytes32 _name, address _mappedAddress) public {
# );
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 21,22] Evaluation Results:
# Inserted Require: require(!unlocked);
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#     }
#
#     function unlock() public {
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress =);,require(!unlocked);
#
# === Evaluating patches for contract: name_registrar.sol ===
#
# [Patch on line 22,31] Evaluation Results:
# Inserted Require: require(!unlocked);,require(msg.sender == owner);
#         unlocked = true;
#     }
#
#     function register(bytes32 _name, address _mappedAddress) public {
#         // set up the new NameRecord
#         NameRecord newRecord;
#         newRecord.name = _name;
#         newRecord.mappedAddress = _mappedAddress;
#
#         resolve[_name] = _mappedAddress;
#         registeredNameRecord[msg.sender] = newRecord;
#
#         require(unlocked); // only allow registrations if contract is unlocked
#     }
# }
#
# pragma solidity ^0.4.15;
# contract NameRegistrar {
#
#     bool public unlocked = false;  // registrar locked, no name updates
#
#     struct NameRecord { // map hashes to addresses
#         bytes32 name;
#         address mappedAddress;
#     }
#
#     mapping(address => NameRecord) public registeredNameRecord; // records who registered names
#     mapping(bytes32 => address) public resolve; // resolves hashes to addresses
#
#     function register(bytes32 _name, address _mappedAddress) public {
# );
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 39] Evaluation Results:
# Inserted Require: require(number <= 10);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38] Evaluation Results:
# Inserted Require: require(number > 0);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 52] Evaluation Results:
# Inserted Require: require(number <= 10);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,52] Evaluation Results:
# Inserted Require: require(number > 0);,require(number <= 10);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,39,52] Evaluation Results:
# Inserted Require: require(number > 0);,require(number <= 10);,require(number <= 10);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 38,39] Evaluation Results:
# Inserted Require: require(number > 0);,require(number <= 10);
#
# === Evaluating patches for contract: crypto_roulette.sol ===
#
# [Patch on line 39,52] Evaluation Results:
# Inserted Require: require(number <= 10);,require(number <= 10);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(target != address(0));
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);,require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,13,15] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);,require(target != address(0));,require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,13] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);,require(target != address(0));
#
# === Evaluating patches for contract: 0xb11b2fed6c9354f7aa2f658d3b4d7b31d8a13b77.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(target != address(0));,require(target.call.value(msg.value)(data));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));,require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);,require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);,require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 96] Evaluation Results:
# Inserted Require: require(msg.sender.send(_wei));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(Holders[_addr]>=_wei);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 101] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value-_wei));
#         msg.sender.call.value(msg.value-_wei);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,101] Evaluation Results:
# Inserted Require: require(Holders[_addr]>=_wei);,require(msg.sender.send(msg.value-_wei));
#         msg.sender.call.value(msg.value-_wei);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,96,101] Evaluation Results:
# Inserted Require: require(Holders[_addr]>=_wei);,require(msg.sender.send(_wei));,require(msg.sender.send(msg.value-_wei));
#         msg.sender.call.value(msg.value-_wei);
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 92,96] Evaluation Results:
# Inserted Require: require(Holders[_addr]>=_wei);,require(msg.sender.send(_wei));
#
# === Evaluating patches for contract: 0x39cfd754c85023648bf003bea2dd498c5612abfa.sol ===
#
# [Patch on line 96,101] Evaluation Results:
# Inserted Require: require(msg.sender.send(_wei));,require(msg.sender.send(msg.value-_wei));
#         msg.sender.call.value(msg.value-_wei);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.sender == from);
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 20] Evaluation Results:
# Inserted Require: require(true);
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,20] Evaluation Results:
# Inserted Require: require(msg.sender == from);,require(true);
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,16,20] Evaluation Results:
# Inserted Require: require(msg.sender == from);,require(caddress.call(id,from,_tos[i],v));,require(true);
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 13,16] Evaluation Results:
# Inserted Require: require(msg.sender == from);,require(caddress.call(id,from,_tos[i],v));
#
# === Evaluating patches for contract: 0x4b71ad9c1a84b9b643aa54fdd66e2dec96e8b152.sol ===
#
# [Patch on line 16,20] Evaluation Results:
# Inserted Require: require(caddress.call(id,from,_tos[i],v));,require(true);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(target != address(0));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 15] Evaluation Results:
# Inserted Require: require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);,require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,13,15] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);,require(target != address(0));,require(target.call.value(msg.value)(data));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,13] Evaluation Results:
# Inserted Require: require(msg.sender == Owner);,require(target != address(0));
#
# === Evaluating patches for contract: 0xbaa3de6504690efb064420d89e871c27065cdd52.sol ===
#
# [Patch on line 13,15] Evaluation Results:
# Inserted Require: require(target != address(0));,require(target.call.value(msg.value)(data));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,0));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
# require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,0));,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
# require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,0));,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
# require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,0));,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
# require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 96] Evaluation Results:
# Inserted Require: require(msg.sender.send(_wei));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92] Evaluation Results:
# Inserted Require: require(_wei<=Holders[msg.sender]);
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 101] Evaluation Results:
# Inserted Require: require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
# require(msg.sender.send(_wei));
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
# require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Hold);
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,101] Evaluation Results:
# Inserted Require: require(_wei<=Holders[msg.sender]);,require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
# require(msg.sender.send(_wei));
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
# require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Hold);
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,96,101] Evaluation Results:
# Inserted Require: require(_wei<=Holders[msg.sender]);,require(msg.sender.send(_wei));,require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
# require(msg.sender.send(_wei));
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
# require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Hold);
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 92,96] Evaluation Results:
# Inserted Require: require(_wei<=Holders[msg.sender]);,require(msg.sender.send(_wei));
#
# === Evaluating patches for contract: 0x3a0e9acd953ffc0dd18d63603488846a6b8b2b01.sol ===
#
# [Patch on line 96,101] Evaluation Results:
# Inserted Require: require(msg.sender.send(_wei));,require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Holders[_addr]>=_wei)
#             {
# require(msg.sender.send(_wei));
#                 _addr.call.value(_wei);
#                 Holders[_addr]-=_wei;
#             }
#         }
# require(msg.sender.send(Holders[msg.sender]-_wei));
#         Holders[msg.sender]-=_wei;
#     }
#
#     function WithdrawToHolder(address _addr, uint _wei)
#     public
#     onlyOwner
#     payable
#     {
# require(_wei<=Holders[msg.sender]);
#         if(Holders[msg.sender]>0)
#         {
#             if(Hold);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 13] Evaluation Results:
# Inserted Require: require(_tos[i]!=address(0));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10] Evaluation Results:
# Inserted Require: require(from!=address(0));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(false);
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,17] Evaluation Results:
# Inserted Require: require(from!=address(0));,require(false);
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,13,17] Evaluation Results:
# Inserted Require: require(from!=address(0));,require(_tos[i]!=address(0));,require(false);
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 10,13] Evaluation Results:
# Inserted Require: require(from!=address(0));,require(_tos[i]!=address(0));
#
# === Evaluating patches for contract: 0x2972d548497286d18e92b5fa1f8f9139e5653fd2.sol ===
#
# [Patch on line 13,17] Evaluation Results:
# Inserted Require: require(_tos[i]!=address(0));,require(false);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));,require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);,require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,43] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("transfer(address,uint256)")),msg.sender,amount));,require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 43,45] Evaluation Results:
# Inserted Require: require(token.call(bytes4(sha3("balanceOf(address)")),msg.sender)>0);,require(token.call(bytes4(sha3("balanceOf(address)")),to)>0);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 93] Evaluation Results:
# Inserted Require: require(_wei<=Holders[_addr]);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 91] Evaluation Results:
# Inserted Require: require(_wei<=Holders[_addr]);
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 99] Evaluation Results:
# Inserted Require: require(Holders[_addr]>0);
#         if(Holders[_addr]>0)
#         {
#             Holders[_addr]=0;
#             if(msg.sender.call.value(_wei)())
#             {
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#     function WithdrawToOwner(uint _wei)
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[owner]>0)
#         {
#             if(owner.call.value(_wei)())
#             {
#                 Holders[owner]-=_wei;
#             }
#         }
#     }
#
#     function WithdrawToOwner()
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[owner]>0)
#         {
#             if(owner.call.value(Holders[owner])())
#             {
#                 Holders[owner]=0;
#             }
#         }
#     }
#
#     function WithdrawToOwner(address _addr, uint _wei)
#     public
#     onlyOwner
# );
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 91,99] Evaluation Results:
# Inserted Require: require(_wei<=Holders[_addr]);,require(Holders[_addr]>0);
#         if(Holders[_addr]>0)
#         {
#             Holders[_addr]=0;
#             if(msg.sender.call.value(_wei)())
#             {
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#     function WithdrawToOwner(uint _wei)
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[owner]>0)
#         {
#             if(owner.call.value(_wei)())
#             {
#                 Holders[owner]-=_wei;
#             }
#         }
#     }
#
#     function WithdrawToOwner()
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[owner]>0)
#         {
#             if(owner.call.value(Holders[owner])())
#             {
#                 Holders[owner]=0;
#             }
#         }
#     }
#
#     function WithdrawToOwner(address _addr, uint _wei)
#     public
#     onlyOwner
# );
#
# === Evaluating patches for contract: 0x627fa62ccbb1c1b04ffaecd72a53e37fc0e17839.sol ===
#
# [Patch on line 91,93,99] Evaluation Results:
# Inserted Require: require(_wei<=Holders[_addr]);,require(_wei<=Holders[_addr]);,require(Holders[_addr]>0);
#         if(Holders[_addr]>0)
#         {
#             Holders[_addr]=0;
#             if(msg.sender.call.value(_wei)())
#             {
#                 Holders[_addr]-=_wei;
#             }
#         }
#     }
#
#     function WithdrawToOwner(uint _wei)
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[owner]>0)
#         {
#             if(owner.call.value(_wei)())
#             {
#                 Holders[owner]-=_wei;
#             }
#         }
#     }
#
#     function WithdrawToOwner()
#     public
#     onlyOwner
#     payable
#     {
#         if(Holders[owner]>0)
#         {
#             if(owner.call.value(Holders[owner])())
#             {
#                 Holders[owner]=0;
#             }
# ...
#
# [Patch on line 24,26] Evaluation Results:
# Inserted Require: require(count >= input);,require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input;
# require(count >= input);
#         count += input;
# require(count >= input);
#         count -= input);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 42] Evaluation Results:
# Inserted Require: require(msg.value > 0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34] Evaluation Results:
# Inserted Require: require(msg.value >= TICKET_AMOUNT);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 57] Evaluation Results:
# Inserted Require: require(msg.value > 0);
#     }
#
#     // Public function for withdrawing funds from the contract.
#     function withdraw() {
#         // Only owner can withdraw funds.
#         require(msg.sender == bank);
#
#         // Send funds to owner.
#         bank.transfer(this.balance);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,57] Evaluation Results:
# Inserted Require: require(msg.value >= TICKET_AMOUNT);,require(msg.value > 0);
#     }
#
#     // Public function for withdrawing funds from the contract.
#     function withdraw() {
#         // Only owner can withdraw funds.
#         require(msg.sender == bank);
#
#         // Send funds to owner.
#         bank.transfer(this.balance);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,42,57] Evaluation Results:
# Inserted Require: require(msg.value >= TICKET_AMOUNT);,require(msg.value > 0);,require(msg.value > 0);
#     }
#
#     // Public function for withdrawing funds from the contract.
#     function withdraw() {
#         // Only owner can withdraw funds.
#         require(msg.sender == bank);
#
#         // Send funds to owner.
#         bank.transfer(this.balance);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 34,42] Evaluation Results:
# Inserted Require: require(msg.value >= TICKET_AMOUNT);,require(msg.value > 0);
#
# === Evaluating patches for contract: ether_lotto.sol ===
#
# [Patch on line 42,57] Evaluation Results:
# Inserted Require: require(msg.value > 0);,require(msg.value > 0);
#     }
#
#     // Public function for withdrawing funds from the contract.
#     function withdraw() {
#         // Only owner can withdraw funds.
#         require(msg.sender == bank);
#
#         // Send funds to owner.
#         bank.transfer(this.balance);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(block.timestamp >= 1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12] Evaluation Results:
# Inserted Require: require(block.timestamp <= 1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 14] Evaluation Results:
# Inserted Require: require(block.timestamp <= 1546300800);
# require(block.timestamp >= 1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,14] Evaluation Results:
# Inserted Require: require(block.timestamp <= 1546300800);,require(block.timestamp <= 1546300800);
# require(block.timestamp >= 1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,12,14] Evaluation Results:
# Inserted Require: require(block.timestamp <= 1546300800);,require(block.timestamp >= 1546300800);,require(block.timestamp <= 1546300800);
# require(block.timestamp >= 1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,12] Evaluation Results:
# Inserted Require: require(block.timestamp <= 1546300800);,require(block.timestamp >= 1546300800);
#
# === Evaluating patches for contract: timed_crowdsale.sol ===
#
# [Patch on line 12,14] Evaluation Results:
# Inserted Require: require(block.timestamp >= 1546300800);,require(block.timestamp <= 1546300800);
# require(block.timestamp >= 1546300800);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 17] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to play the game and collect funds
#     function play() public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value ==);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,24] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to play the game and collect funds
#     function play() public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);,require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value ==);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,17,24] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to play the game and collect funds
#     function play() public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);,require(msg.value == 10 ether);,require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value ==);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,17] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to play the game and collect funds
#     function play() public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);,require(msg.value == 10 ether);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 17,24] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether);,require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
#         require(now != pastBlockTime); // only 1 transaction per block
#
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
# require(msg.value == 10 ether);
# require(msg.value == 10 ether);
# }
#
# contract Roulette {
#     uint public pastBlockTime; // Forces one bet per block
#
#     constructor() public payable {} // initially fund contract
#
#     // fallback function used to make a bet
#     function () public payable {
# require(msg.value ==);
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 19] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet() public payable {
# require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet2() public payable {
# require(msg.value == 10 ether); // must send 1);
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 24] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,24] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet() public payable {
# require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet2() public payable {
# require(msg.value == 10 ether); // must send 1);,require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,19,24] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet() public payable {
# require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet2() public payable {
# require(msg.value == 10 ether); // must send 1);,require(msg.sender.send(msg.value));,require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 16,19] Evaluation Results:
# Inserted Require: require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet() public payable {
# require(msg.value == 10 ether); // must send 10 ether to play
#
#         require(now != pastBlockTime); // only 1 transaction per block
# require(msg.sender.send(msg.value));
#         pastBlockTime = now;
#         if(now % 15 == 0) { // winner
#             msg.sender.transfer(this.balance);
#         }
#     }
#
#     // allows anyone to call a function on this contract
#     function bet2() public payable {
# require(msg.value == 10 ether); // must send 1);,require(msg.sender.send(msg.value));
#
# === Evaluating patches for contract: roulette.sol ===
#
# [Patch on line 19,24] Evaluation Results:
# Inserted Require: require(msg.sender.send(msg.value));,require(msg.sender.send(msg.value));
# Row written to '/home/matteo/FLAMES/validation-results/sb-heists/reports/aggregated/validation_results_CL.csv' (Excel-friendly format).
